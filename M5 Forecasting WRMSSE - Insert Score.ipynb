# %%
import math
import pandas as pd
import numpy as np
import datetime as dt
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVR
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_squared_log_error
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LogisticRegression,LinearRegression,BayesianRidge, Lasso
from statistics import mean
from math import sqrt
import tensorflow as tf
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import LSTM, Bidirectional
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras import Input, layers
from tensorflow.keras import optimizers
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping

import datetime
import warnings
from tqdm import tqdm
from pathlib import Path
import time
from copy import deepcopy
import os

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
def read_data():
    calendar = pd.read_csv('calendar.csv')
    calendar = reduce_mem_usage(calendar)
    print('Calendar has {} rows and {} columns'.format(calendar.shape[0], calendar.shape[1]))
    sell_prices = pd.read_csv('sell_prices.csv')
    sell_prices = reduce_mem_usage(sell_prices)
    print('Sell prices has {} rows and {} columns'.format(sell_prices.shape[0], sell_prices.shape[1]))
    sales_train_validation = pd.read_csv('sales_train_validation.csv')
    print('Sales train validation has {} rows and {} columns'.format(sales_train_validation.shape[0], sales_train_validation.shape[1]))
    submission = pd.read_csv('sample_submission.csv')
    return calendar, sell_prices, sales_train_validation, submission

# %%
def melt_and_merge(calendar, sell_prices, sales_train_validation, submission, nrows = 55000000, merge = False):
    
    # melt sales data, get it ready for training
    sales_train_validation = pd.melt(sales_train_validation, id_vars = ['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'], var_name = 'day', value_name = 'demand')
    print('Melted sales train validation has {} rows and {} columns'.format(sales_train_validation.shape[0], sales_train_validation.shape[1]))
    sales_train_validation = reduce_mem_usage(sales_train_validation)
    
    # seperate test dataframes
    test1_rows = [row for row in submission['id'] if 'validation' in row]
    test2_rows = [row for row in submission['id'] if 'evaluation' in row]
    test1 = submission[submission['id'].isin(test1_rows)]
    test2 = submission[submission['id'].isin(test2_rows)]
    
    # change column names
    test1.columns = ['id', 'd_1914', 'd_1915', 'd_1916', 'd_1917', 'd_1918', 'd_1919', 'd_1920', 'd_1921', 'd_1922', 'd_1923', 'd_1924', 'd_1925', 'd_1926', 'd_1927', 'd_1928', 'd_1929', 'd_1930', 'd_1931', 
                      'd_1932', 'd_1933', 'd_1934', 'd_1935', 'd_1936', 'd_1937', 'd_1938', 'd_1939', 'd_1940', 'd_1941']
    test2.columns = ['id', 'd_1942', 'd_1943', 'd_1944', 'd_1945', 'd_1946', 'd_1947', 'd_1948', 'd_1949', 'd_1950', 'd_1951', 'd_1952', 'd_1953', 'd_1954', 'd_1955', 'd_1956', 'd_1957', 'd_1958', 'd_1959', 
                      'd_1960', 'd_1961', 'd_1962', 'd_1963', 'd_1964', 'd_1965', 'd_1966', 'd_1967', 'd_1968', 'd_1969']
    
    # get product table
    product = sales_train_validation[['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id']].drop_duplicates()
    
    # merge with product table
    test2['id'] = test2['id'].str.replace('_evaluation','_validation')
    test1 = test1.merge(product, how = 'left', on = 'id')
    test2 = test2.merge(product, how = 'left', on = 'id')
    test2['id'] = test2['id'].str.replace('_validation','_evaluation')
    
    test1 = pd.melt(test1, id_vars = ['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'], var_name = 'day', value_name = 'demand')
    test2 = pd.melt(test2, id_vars = ['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id'], var_name = 'day', value_name = 'demand')
    
    sales_train_validation['part'] = 'train'
    test1['part'] = 'test1'
    test2['part'] = 'test2'
    
    data = pd.concat([sales_train_validation, test1, test2], axis = 0)
    
    del sales_train_validation, test1, test2
    
    data = data.loc[nrows:]
    
    calendar.drop(['weekday', 'wday', 'month', 'year'], inplace = True, axis = 1)
    
    # delete test2 for now, don't delete when we do next stage of testing in June 
    data = data[data['part'] != 'test2']
    
    if merge:
        data = pd.merge(data, calendar, how = 'left', left_on = ['day'], right_on = ['d'])
        data.drop(['d', 'day'], inplace = True, axis = 1)
        data = data.merge(sell_prices, on = ['store_id', 'item_id', 'wm_yr_wk'], how = 'left')
        print('Our final dataset to train has {} rows and {} columns'.format(data.shape[0], data.shape[1]))
    else: 
        pass

    
    return data

# %%
import pandas as pd
pd.options.mode.chained_assignment = None 

calendar, sell_prices, sales_train_validation, submission = read_data()

data = melt_and_merge(calendar, sell_prices, sales_train_validation, submission, nrows = 30000000, merge = True)
# Out:
# Mem. usage decreased to  0.12 Mb (41.9% reduction)
# Calendar has 1969 rows and 14 columns
# Mem. usage decreased to 130.48 Mb (37.5% reduction)
# Sell prices has 6841121 rows and 4 columns
# Sales train validation has 30490 rows and 1919 columns
# Melted sales train validation has 58327370 rows and 8 columns
# Mem. usage decreased to 3226.27 Mb (9.4% reduction)
# Our final dataset to train has 29181090 rows and 18 columns

# %%
data.to_csv("TrainingData30mil")

# %%
TARGET = 'sales'      
END_TEST = 1913      
ID_COLS = ['id', 'item_id', 'dept_id', 'cat_id', 'store_id', 'state_id']

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns; sns.set()
import gc

from sklearn import preprocessing
import lightgbm as lgb

from typing import Union
from tqdm.notebook import tqdm_notebook as tqdm

DATA_DIR = '/kaggle/input/m5-forecasting-accuracy/'

class WRMSSEEvaluator_dashboard(object):

    def __init__(self, train_df: pd.DataFrame, valid_df: pd.DataFrame, 
                 calendar: pd.DataFrame, prices: pd.DataFrame):
        train_y = train_df.loc[:, train_df.columns.str.startswith('d_')]
        train_target_columns = train_y.columns.tolist()
        weight_columns = train_y.iloc[:, -28:].columns.tolist()

        train_df['all_id'] = 'all'  # for lv1 aggregation

        id_columns = train_df.loc[:, ~train_df.columns.str.startswith('d_')]\
                     .columns.tolist()
        valid_target_columns = valid_df.loc[:, valid_df.columns.str.startswith('d_')]\
                               .columns.tolist()

        if not all([c in valid_df.columns for c in id_columns]):
            valid_df = pd.concat([train_df[id_columns], valid_df], 
                                 axis=1, sort=False)

        self.train_df = train_df
        self.valid_df = valid_df
        self.calendar = calendar
        self.prices = prices

        self.weight_columns = weight_columns
        self.id_columns = id_columns
        self.valid_target_columns = valid_target_columns

        weight_df = self.get_weight_df()

        self.group_ids = (
            'all_id',
            'state_id',
            'store_id',
            'cat_id',
            'dept_id',
            ['state_id', 'cat_id'],
            ['state_id', 'dept_id'],
            ['store_id', 'cat_id'],
            ['store_id', 'dept_id'],
            'item_id',
            ['item_id', 'state_id'],
            ['item_id', 'store_id']
        )

        for i, group_id in enumerate(tqdm(self.group_ids)):
            train_y = train_df.groupby(group_id)[train_target_columns].sum()
            scale = []
            for _, row in train_y.iterrows():
                series = row.values[np.argmax(row.values != 0):]
                scale.append(((series[1:] - series[:-1]) ** 2).mean())
            setattr(self, f'lv{i + 1}_scale', np.array(scale))
            setattr(self, f'lv{i + 1}_train_df', train_y)
            setattr(self, f'lv{i + 1}_valid_df', valid_df.groupby(group_id)\
                    [valid_target_columns].sum())

            lv_weight = weight_df.groupby(group_id)[weight_columns].sum().sum(axis=1)
            setattr(self, f'lv{i + 1}_weight', lv_weight / lv_weight.sum())

    def get_weight_df(self) -> pd.DataFrame:
        day_to_week = self.calendar.set_index('d')['wm_yr_wk'].to_dict()
        weight_df = self.train_df[['item_id', 'store_id'] + self.weight_columns]\
                    .set_index(['item_id', 'store_id'])
        weight_df = weight_df.stack().reset_index()\
                   .rename(columns={'level_2': 'd', 0: 'value'})
        weight_df['wm_yr_wk'] = weight_df['d'].map(day_to_week)

        weight_df = weight_df.merge(self.prices, how='left',
                                    on=['item_id', 'store_id', 'wm_yr_wk'])
        weight_df['value'] = weight_df['value'] * weight_df['sell_price']
        weight_df = weight_df.set_index(['item_id', 'store_id', 'd'])\
                    .unstack(level=2)['value']\
                    .loc[zip(self.train_df.item_id, self.train_df.store_id), :]\
                    .reset_index(drop=True)
        weight_df = pd.concat([self.train_df[self.id_columns],
                               weight_df], axis=1, sort=False)
        return weight_df

    def rmsse(self, valid_preds: pd.DataFrame, lv: int) -> pd.Series:
        valid_y = getattr(self, f'lv{lv}_valid_df')
        score = ((valid_y - valid_preds) ** 2).mean(axis=1)
        scale = getattr(self, f'lv{lv}_scale')
        return (score / scale).map(np.sqrt) 

    def score(self, valid_preds: Union[pd.DataFrame, 
                                       np.ndarray]) -> float:
        assert self.valid_df[self.valid_target_columns].shape \
               == valid_preds.shape

        if isinstance(valid_preds, np.ndarray):
            valid_preds = pd.DataFrame(valid_preds, 
                                       columns=self.valid_target_columns)

        valid_preds = pd.concat([self.valid_df[self.id_columns], 
                                 valid_preds], axis=1, sort=False)

        all_scores = []
        for i, group_id in enumerate(self.group_ids):

            valid_preds_grp = valid_preds.groupby(group_id)[self.valid_target_columns].sum()
            setattr(self, f'lv{i + 1}_valid_preds', valid_preds_grp)
            
            lv_scores = self.rmsse(valid_preds_grp, i + 1)
            setattr(self, f'lv{i + 1}_scores', lv_scores)
            
            weight = getattr(self, f'lv{i + 1}_weight')
            lv_scores = pd.concat([weight, lv_scores], axis=1, 
                                  sort=False).prod(axis=1)
            
            all_scores.append(lv_scores.sum())
            
        self.all_scores = all_scores

        return np.mean(all_scores)
    

    
def create_viz_df(df,lv):
    
    df = df.T.reset_index()
    if lv in [6,7,8,9,11,12]:
        df.columns = [i[0] + '_' + i[1] if i != ('index','') \
                      else i[0] for i in df.columns]
    df = df.merge(calendar.loc[:, ['d','date']], how='left', 
                  left_on='index', right_on='d')
    df['date'] = pd.to_datetime(df.date)
    df = df.set_index('date')
    df = df.drop(['index', 'd'], axis=1)
    
    return df

def create_dashboard(evaluator, by_level_only=False, model_name=None):
    
    wrmsses = [np.mean(evaluator.all_scores)] + evaluator.all_scores
    labels = ['Overall'] + [f'Level {i}' for i in range(1, 13)]

    ## WRMSSE by Level
    plt.figure(figsize=(12,5))
    ax = sns.barplot(x=labels, y=wrmsses)
    ax.set(xlabel='', ylabel='WRMSSE')
    
    #######################ALTERATION##########################
    title = 'WRMSSE by Level'
    if model_name: 
        title = f'WRMSSE by Level for {model_name}'
    plt.title(title, fontsize=20, fontweight='bold')
    #######################ALTERATION-COMPLETE##########################

  
    for index, val in enumerate(wrmsses):
        ax.text(index*1, val+.01, round(val,4), color='black', 
                ha="center")
        
    #######################ALTERATION##########################
    if by_level_only:       # stops function early for quick plotting of 
        plt.show()          # for quick plotting of levels
        return
    #######################ALTERATION-COMPLETE##########################

    # configuration array for the charts
    n_rows = [1, 1, 4, 1, 3, 3, 3, 3, 3, 3, 3, 3]
    n_cols = [1, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3]
    width = [7, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14]
    height = [4, 3, 12, 3, 9, 9, 9, 9, 9, 9, 9, 9]
    
    for i in range(1,13):
        
        scores = getattr(evaluator, f'lv{i}_scores')
        weights = getattr(evaluator, f'lv{i}_weight')
        
        if i > 1 and i < 9:
            if i < 7:
                fig, axs = plt.subplots(1, 2, figsize=(12, 3))
            else:
                fig, axs = plt.subplots(2, 1, figsize=(12, 8))
                
            ## RMSSE plot
            scores.plot.bar(width=.8, ax=axs[0], color='g')
            axs[0].set_title(f"RMSSE", size=14)
            axs[0].set(xlabel='', ylabel='RMSSE')
            if i >= 4:
                axs[0].tick_params(labelsize=8)
            for index, val in enumerate(scores):
                axs[0].text(index*1, val+.01, round(val,4), color='black', 
                            ha="center", fontsize=10 if i == 2 else 8)
            
            ## Weight plot
            weights.plot.bar(width=.8, ax=axs[1])
            axs[1].set_title(f"Weight", size=14)
            axs[1].set(xlabel='', ylabel='Weight')
            if i >= 4:
                axs[1].tick_params(labelsize=8)
            for index, val in enumerate(weights):
                axs[1].text(index*1, val+.01, round(val,2), color='black', 
                            ha="center", fontsize=10 if i == 2 else 8)
                    
            fig.suptitle(f'Level {i}: {evaluator.group_ids[i-1]}', size=24 ,
                         y=1.1, fontweight='bold')
            plt.tight_layout()
            plt.show()

        trn = create_viz_df(getattr(evaluator, f'lv{i}_train_df')\
                            .iloc[:, -28*3:], i)
        val = create_viz_df(getattr(evaluator, f'lv{i}_valid_df'), i)
        pred = create_viz_df(getattr(evaluator, f'lv{i}_valid_preds'), i)

        n_cate = trn.shape[1] if i < 7 else 9

        fig, axs = plt.subplots(n_rows[i-1], n_cols[i-1], 
                                figsize=(width[i-1],height[i-1]))
        if i > 1:
            axs = axs.flatten()

        ## Time series plot
        for k in range(0, n_cate):

            ax = axs[k] if i > 1 else axs

            trn.iloc[:, k].plot(ax=ax, label='train')
            val.iloc[:, k].plot(ax=ax, label='valid')
            pred.iloc[:, k].plot(ax=ax, label='pred')
            ax.set_title(f"{trn.columns[k]}  RMSSE:{scores[k]:.4f}", size=14)
            ax.set(xlabel='', ylabel='sales')
            ax.tick_params(labelsize=8)
            ax.legend(loc='upper left', prop={'size': 10})

        if i == 1 or i >= 9:
            fig.suptitle(f'Level {i}: {evaluator.group_ids[i-1]}', size=24 , 
                         y=1.1, fontweight='bold')
        plt.tight_layout()
        plt.show()
        
train_df = pd.read_csv('sales_train_validation.csv')
calendar_df = pd.read_csv('calendar.csv')
sell_prices_df = pd.read_csv('sell_prices.csv')
train_df = train_df.loc[:, :'d_' + str(END_TEST)]

train_fold_df = train_df.iloc[:, :-28]
valid_fold_df = train_fold_df.iloc[:, -28:].copy()
# Instantiate an evaluator for scoring validation periodstarting day 1886
e = WRMSSEEvaluator_dashboard(train_fold_df, valid_fold_df, calendar_df, sell_prices_df)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))

# %%
cols = ["d_{}".format(i) for i in range(1914-28, 1914)]
lastdata = sales_train_validation[["id", 'store_id', 'item_id'] + cols]

# To long form:
lastdata = lastdata.melt(id_vars=["id", 'store_id', 'item_id'], 
                 var_name="d", value_name="sale")

# Add week of year column from 'calendar':
lastdata = pd.merge(lastdata, calendar, how = 'left', 
                left_on = ['d'], right_on = ['d'])

lastdata = lastdata[["id", 'store_id', 'item_id', "sale", "d", "wm_yr_wk"]]

# Add weekly price from 'sell_prices':
lastdata = lastdata.merge(sell_prices, on = ['store_id', 'item_id', 'wm_yr_wk'], how = 'left')
lastdata.drop(columns = ['wm_yr_wk'], inplace=True)

# Calculate daily sales in USD:
lastdata['sale_usd'] = lastdata['sale'] * lastdata['sell_price']
lastdata.head()
# Out:
#                               id store_id        item_id  sale       d  \
# 0  HOBBIES_1_001_CA_1_validation     CA_1  HOBBIES_1_001     1  d_1886
# 1  HOBBIES_1_002_CA_1_validation     CA_1  HOBBIES_1_002     1  d_1886
# 2  HOBBIES_1_003_CA_1_validation     CA_1  HOBBIES_1_003     0  d_1886
# 3  HOBBIES_1_004_CA_1_validation     CA_1  HOBBIES_1_004     0  d_1886
# 4  HOBBIES_1_005_CA_1_validation     CA_1  HOBBIES_1_005     1  d_1886
#
#    sell_price  sale_usd
# 0    8.257812  8.257812
# 1    3.970703  3.970703
# 2    2.970703  0.000000
# 3    4.640625  0.000000
# 4    2.880859  2.880859

# %%
sales = sales_train_validation

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from scipy.sparse import csr_matrix
import gc

# %%
dummies_list = [sales.state_id, sales.store_id, 
                sales.cat_id, sales.dept_id, 
                sales.state_id +'_'+ sales.cat_id, sales.state_id +'_'+ sales.dept_id,
                sales.store_id +'_'+ sales.cat_id, sales.store_id +'_'+ sales.dept_id, 
                sales.item_id, sales.state_id +'_'+ sales.item_id, sales.id]


## First element Level_0 aggregation 'all_sales':
dummies_df_list =[pd.DataFrame(np.ones(sales.shape[0]).astype(np.int8), 
                               index=sales.index, columns=['all']).T]

# List of dummy dataframes:
for i, cats in enumerate(dummies_list):
    dummies_df_list +=[pd.get_dummies(cats, drop_first=False, dtype=np.int8).T]
    
# Concat dummy dataframes in one go:
## Level is constructed for free.
roll_mat_df = pd.concat(dummies_df_list, keys=list(range(12)), 
                        names=['level','id'])#.astype(np.int8, copy=False)

# Save values as sparse matrix & save index for future reference:
roll_index = roll_mat_df.index
roll_mat_csr = csr_matrix(roll_mat_df.values)
roll_mat_csr.shape
# Out:
# (42840, 30490)

# %%
roll_mat_df.to_pickle('roll_mat_df.pkl')
del dummies_df_list, roll_mat_df
gc.collect()
# Out:
# 23

# %%
def get_s(drop_days=0):
    # Rollup sales:
    d_name = ['d_' + str(i+1) for i in range(1913-drop_days)]
    sales_train_val = roll_mat_csr * sales[d_name].values

    no_sales = np.cumsum(sales_train_val, axis=1) == 0
    sales_train_val = np.where(no_sales, np.nan, sales_train_val)

    # Denominator of RMSSE / RMSSE
    weight1 = np.nanmean(np.diff(sales_train_val,axis=1)**2,axis=1)
    
    return weight1

# %%
S = get_s(drop_days=0)
S.shape
# Out:
# (42840,)

# %%
S[10:]
# Out:
# array([3.26268315e+05, 5.14239651e+05, 5.17917913e+05, ...,
#        1.71293871e-01, 6.98666667e-02, 2.81004710e-01])

# %%
def get_w(sale_usd):
    """
    """
    # Calculate the total sales in USD for each item id:
    total_sales_usd = sale_usd.groupby(
        ['id'], sort=False)['sale_usd'].apply(np.sum).values
    
    # Roll up total sales by ids to higher levels:
    weight2 = roll_mat_csr * total_sales_usd
    
    return 12*weight2/np.sum(weight2)

# %%
W = get_w(lastdata[['id','sale_usd']])
W.shape
# Out:
# (42840,)

# %%
W_df = pd.DataFrame(W,index = roll_index,columns=['w'])

W_original_df = pd.read_csv('weights_validation.csv')

# Set new index, calculate difference between original and predicted:
W_original_df = W_original_df.set_index(W_df.index)
W_original_df['Predicted'] = W_df.w
W_original_df['diff'] = W_original_df.Weight - W_original_df.Predicted

# See where we are off by more than e-6
m = W_original_df.Weight.values - W_df.w.values > 0.000001
W_original_df[m]
# Out:
#                      Level_id  Agg_Level_1  Agg_Level_2    Weight  Predicted  \
# level id
# 1     CA               Level2           CA            X  0.442371   0.442370
# 3     HOBBIES          Level4      HOBBIES            X  0.128079   0.128075
#       HOUSEHOLD        Level4    HOUSEHOLD            X  0.303335   0.303330
# 4     FOODS_1          Level5      FOODS_1            X  0.062625   0.062623
#       FOODS_2          Level5      FOODS_2            X  0.154642   0.154639
#       HOBBIES_1        Level5    HOBBIES_1            X  0.122088   0.122084
#       HOUSEHOLD_1      Level5  HOUSEHOLD_1            X  0.229594   0.229592
#       HOUSEHOLD_2      Level5  HOUSEHOLD_2            X  0.073741   0.073738
# 5     CA_HOBBIES       Level6           CA      HOBBIES  0.058855   0.058852
#       CA_HOUSEHOLD     Level6           CA    HOUSEHOLD  0.142772   0.142769
#       TX_HOUSEHOLD     Level6           TX    HOUSEHOLD  0.086420   0.086419
#       WI_HOBBIES       Level6           WI      HOBBIES  0.027931   0.027930
# 6     CA_FOODS_2       Level7           CA      FOODS_2  0.057655   0.057654
#       CA_HOBBIES_1     Level7           CA    HOBBIES_1  0.056463   0.056460
#       CA_HOUSEHOLD_1   Level7           CA  HOUSEHOLD_1  0.104863   0.104862
#       CA_HOUSEHOLD_2   Level7           CA  HOUSEHOLD_2  0.037909   0.037907
#       TX_FOODS_1       Level7           TX      FOODS_1  0.016016   0.016015
#       WI_FOODS_2       Level7           WI      FOODS_2  0.062561   0.062560
#       WI_HOBBIES_1     Level7           WI    HOBBIES_1  0.026375   0.026374
# 7     CA_2_HOUSEHOLD   Level8         CA_2    HOUSEHOLD  0.037630   0.037629
#       CA_3_HOUSEHOLD   Level8         CA_3    HOUSEHOLD  0.055870   0.055869
# 8     WI_2_FOODS_2     Level9         WI_2      FOODS_2  0.030535   0.030534
# 9     FOODS_2_029     Level10  FOODS_2_029            X  0.002862   0.002861
#       FOODS_2_183     Level10  FOODS_2_183            X  0.002679   0.002677
#       FOODS_3_586     Level10  FOODS_3_586            X  0.005074   0.005073
#
#                           diff
# level id
# 1     CA              0.000002
# 3     HOBBIES         0.000004
#       HOUSEHOLD       0.000005
# 4     FOODS_1         0.000002
#       FOODS_2         0.000004
#       HOBBIES_1       0.000004
#       HOUSEHOLD_1     0.000002
#       HOUSEHOLD_2     0.000003
# 5     CA_HOBBIES      0.000003
#       CA_HOUSEHOLD    0.000004
#       TX_HOUSEHOLD    0.000001
#       WI_HOBBIES      0.000001
# 6     CA_FOODS_2      0.000001
#       CA_HOBBIES_1    0.000003
#       CA_HOUSEHOLD_1  0.000002
#       CA_HOUSEHOLD_2  0.000002
#       TX_FOODS_1      0.000001
#       WI_FOODS_2      0.000002
#       WI_HOBBIES_1    0.000001
# 7     CA_2_HOUSEHOLD  0.000001
#       CA_3_HOUSEHOLD  0.000001
# 8     WI_2_FOODS_2    0.000001
# 9     FOODS_2_029     0.000001
#       FOODS_2_183     0.000001
#       FOODS_3_586     0.000001

# %%
SW = W/np.sqrt(S)
sw_df = pd.DataFrame(np.stack((S, W, SW), axis=-1),index = roll_index,columns=['s','w','sw'])
sw_df.to_pickle('sw_df.pkl')

# %%
def rollup(v):
    return roll_mat_csr*v #(v.T*roll_mat_csr.T).T


# Function to calculate WRMSSE:
def wrmsse(preds, y_true, score_only=False, s = S, w = W, sw=SW):
    if score_only:
        return np.sum(
                np.sqrt(
                    np.mean(
                        np.square(rollup(preds.values-y_true.values))
                            ,axis=1)) * sw)/12 #<-used to be mistake here
    else: 
        score_matrix = (np.square(rollup(preds.values-y_true.values)) * np.square(w)[:, None])/ s[:, None]
        score = np.sum(np.sqrt(np.mean(score_matrix,axis=1)))/12 #<-used to be mistake here
        return score, score_matrix

# %%
sw_df = pd.read_pickle('sw_df.pkl')
S = sw_df.s.values
W = sw_df.w.values
SW = sw_df.sw.values

# Load roll up matrix to calcualte aggreagates:
roll_mat_df = pd.read_pickle('roll_mat_df.pkl')
roll_index = roll_mat_df.index
roll_mat_csr = csr_matrix(roll_mat_df.values)
del roll_mat_df

# %%
def wrmsse_eval(preds, y_true, s = S, w = W, sw=SW):
    score = np.sum(
                np.sqrt(
                    np.mean(
                        np.square(rollup(preds.values-y_true.values))
                            ,axis=1)) * sw)/12 

    return "WRMSSE", score, False

# %%
from sklearn.preprocessing import LabelEncoder

def transform(data):
    
    nan_features = ['event_name_1', 'event_type_1', 'event_name_2', 'event_type_2']
    for feature in nan_features:
        data[feature].fillna('unknown', inplace = True)
        
    cat = ['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'event_name_1', 'event_type_1', 'event_name_2', 'event_type_2']
    for feature in cat:
        encoder = LabelEncoder()
        data[feature] = encoder.fit_transform(data[feature])
        
    data = reduce_mem_usage(data)
    return data

# %%
def lag_features(data):
    
    data_fe = data[['id', 'demand']]
    
    window = 28
    periods = [7, 14, 28, 84]
    group = data_fe.groupby('id')['demand']
    
    # most recent lag data
    for period in periods:
        data_fe['demand_rolling_mean_t' + str(period)] = group.transform(lambda x: x.shift(window).rolling(period).mean())
        data_fe['demand_rolling_std_t' + str(period)] = group.transform(lambda x: x.shift(window).rolling(period).std())
        
    # reduce memory
    data_fe = reduce_mem_usage(data_fe)
    
    # get time features
    data['date'] = pd.to_datetime(data['date'])
    time_features = ['year', 'month', 'quarter', 'week', 'day', 'dayofweek', 'dayofyear']
    dtype = np.int16
    for time_feature in time_features:
        data[time_feature] = getattr(data['date'].dt, time_feature).astype(dtype)
        
    lag_rolling_features = [col for col in data_fe.columns if col not in ['id', 'demand']]
    data = pd.concat([data, data_fe[lag_rolling_features]], axis = 1)
    
    del data_fe

    return data

# %%
data.tail()
# Out:
#                                    id      item_id  dept_id cat_id store_id  \
# 29181085  FOODS_3_823_WI_3_validation  FOODS_3_823  FOODS_3  FOODS     WI_3
# 29181086  FOODS_3_824_WI_3_validation  FOODS_3_824  FOODS_3  FOODS     WI_3
# 29181087  FOODS_3_825_WI_3_validation  FOODS_3_825  FOODS_3  FOODS     WI_3
# 29181088  FOODS_3_826_WI_3_validation  FOODS_3_826  FOODS_3  FOODS     WI_3
# 29181089  FOODS_3_827_WI_3_validation  FOODS_3_827  FOODS_3  FOODS     WI_3
#
#          state_id  demand   part        date  wm_yr_wk event_name_1  \
# 29181085       WI       0  test1  2016-05-22     11617          NaN
# 29181086       WI       0  test1  2016-05-22     11617          NaN
# 29181087       WI       0  test1  2016-05-22     11617          NaN
# 29181088       WI       0  test1  2016-05-22     11617          NaN
# 29181089       WI       0  test1  2016-05-22     11617          NaN
#
#          event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI  \
# 29181085          NaN          NaN          NaN        0        0        0
# 29181086          NaN          NaN          NaN        0        0        0
# 29181087          NaN          NaN          NaN        0        0        0
# 29181088          NaN          NaN          NaN        0        0        0
# 29181089          NaN          NaN          NaN        0        0        0
#
#           sell_price
# 29181085    2.980469
# 29181086    2.480469
# 29181087    3.980469
# 29181088    1.280273
# 29181089    1.000000

# %%
weights_scales = pd.read_csv("weight_scale_1158.csv")
wdf = pd.read_csv("weight_scale_1886.csv")

# %%
grid_df = pd.concat([pd.read_pickle('grid_part_1.pkl'),
                     pd.read_pickle('grid_part_2.pkl').iloc[:,2:],
                     pd.read_pickle('grid_part_3.pkl').iloc[:,2:]], axis = 1)

# %%
grid_df.tail()
# Out:
#                                    id      item_id  dept_id cat_id store_id  \
# 46881672  FOODS_3_823_WI_3_validation  FOODS_3_823  FOODS_3  FOODS     WI_3
# 46881673  FOODS_3_824_WI_3_validation  FOODS_3_824  FOODS_3  FOODS     WI_3
# 46881674  FOODS_3_825_WI_3_validation  FOODS_3_825  FOODS_3  FOODS     WI_3
# 46881675  FOODS_3_826_WI_3_validation  FOODS_3_826  FOODS_3  FOODS     WI_3
# 46881676  FOODS_3_827_WI_3_validation  FOODS_3_827  FOODS_3  FOODS     WI_3
#
#          state_id     d  sales  release  sell_price  ...  snap_CA  snap_TX  \
# 46881672       WI  1941    NaN        0    2.980469  ...        0        0
# 46881673       WI  1941    NaN        0    2.480469  ...        0        0
# 46881674       WI  1941    NaN        0    3.980469  ...        0        0
# 46881675       WI  1941    NaN      230    1.280273  ...        0        0
# 46881676       WI  1941    NaN      304    1.000000  ...        0        0
#
#           snap_WI  tm_d  tm_w  tm_m  tm_y  tm_wm  tm_dw  tm_w_end
# 46881672        0    22    20     5     5      4      6         1
# 46881673        0    22    20     5     5      4      6         1
# 46881674        0    22    20     5     5      4      6         1
# 46881675        0    22    20     5     5      4      6         1
# 46881676        0    22    20     5     5      4      6         1
#
# [5 rows x 34 columns]

# %%
grid_df = grid_df[(grid_df.d > 1885-90) & (grid_df.d <= END_TEST)]
# Set up test set (day 1886-1913) 
remove_features = ['id','d',TARGET, 'weight', 'scale'] 
features_columns = [col for col in list(grid_df) if col not in remove_features]
test_x = grid_df[grid_df['d']>(END_TEST-28)][features_columns]

test_id = grid_df[grid_df['d']>(END_TEST-28)][['id', 'd']]

# %%
new_grid_df = grid_df[grid_df['d']<=END_TEST].reset_index(drop=True)

# %%
tr_x = new_grid_df[new_grid_df['d']<=(END_TEST-28)]
tr_w = tr_x[ID_COLS]

# %%
wdf.tail(15)
# Out:
#        Unnamed: 0 Level_id      Agg_Level_1 Agg_Level_2    weight     scale
# 42825       42825  Level12  HOUSEHOLD_2_515        TX_2  0.000001  0.444307
# 42826       42826  Level12  HOUSEHOLD_2_515        TX_3  0.000002  0.235367
# 42827       42827  Level12  HOUSEHOLD_2_515        WI_1  0.000002  0.258427
# 42828       42828  Level12  HOUSEHOLD_2_515        WI_2  0.000000  0.248455
# 42829       42829  Level12  HOUSEHOLD_2_515        WI_3  0.000004  0.293451
# 42830       42830  Level12  HOUSEHOLD_2_516        CA_1  0.000008  0.333510
# 42831       42831  Level12  HOUSEHOLD_2_516        CA_2  0.000013  0.458711
# 42832       42832  Level12  HOUSEHOLD_2_516        CA_3  0.000005  0.310143
# 42833       42833  Level12  HOUSEHOLD_2_516        CA_4  0.000002  0.154545
# 42834       42834  Level12  HOUSEHOLD_2_516        TX_1  0.000005  0.243446
# 42835       42835  Level12  HOUSEHOLD_2_516        TX_2  0.000016  0.622411
# 42836       42836  Level12  HOUSEHOLD_2_516        TX_3  0.000008  0.223992
# 42837       42837  Level12  HOUSEHOLD_2_516        WI_1  0.000003  0.172780
# 42838       42838  Level12  HOUSEHOLD_2_516        WI_2  0.000002  0.069843
# 42839       42839  Level12  HOUSEHOLD_2_516        WI_3  0.000003  0.285183

# %%
wdf['scaled_weight'] = wdf.weight/np.sqrt(wdf.scale)
wdf = wdf[[ 'Level_id', 'Agg_Level_1', 'Agg_Level_2','scaled_weight']]


######################### level 1 #######################################
tr_w['level_1_sw'] = wdf.loc[wdf['Level_id'] == 'Level1', 'scaled_weight'][0]

######################### level 2 #######################################
level = wdf[wdf.Level_id == 'Level2']
# Set the name of the aggregation column to match 
# the column in our id columns
level.columns = ['Level_id', 'state_id', 'Agg_Level_2', 'scaled_weight']
level_scaled_weight = pd.merge(tr_w[['state_id']], level[['state_id', 'scaled_weight']],
                               on='state_id', how='left')[['scaled_weight']]
tr_w['level_2_sw'] = level_scaled_weight['scaled_weight'].values

del level, level_scaled_weight

######################### level 3 #######################################
level = wdf[wdf.Level_id == 'Level3']
# Set the name of the aggregation column to match 
# the column in our id columns
level.columns = ['Level_id', 'store_id', 'Agg_Level_2', 'scaled_weight']
level_scaled_weight = pd.merge(tr_w[['store_id']], level[['store_id', 'scaled_weight']],
                               on='store_id', how='left')[['scaled_weight']]
tr_w['level_3_sw'] = level_scaled_weight['scaled_weight'].values

del level, level_scaled_weight

######################### level 4 #######################################
level = wdf[wdf.Level_id == 'Level4']
# Set the name of the aggregation column to match 
# the column in our id columns
level.columns = ['Level_id', 'cat_id', 'Agg_Level_2', 'scaled_weight']
level_scaled_weight = pd.merge(tr_w[['cat_id']], level[['cat_id', 'scaled_weight']],
                               on='cat_id', how='left')[['scaled_weight']]
tr_w['level_4_sw'] = level_scaled_weight['scaled_weight'].values

del level, level_scaled_weight

######################### level 5 #######################################
level = wdf[wdf.Level_id == 'Level5']
# Set the name of the aggregation column to match 
# the column in our id columns
level.columns = ['Level_id', 'dept_id', 'Agg_Level_2', 'scaled_weight']
level_scaled_weight = pd.merge(tr_w[['dept_id']], level[['dept_id', 'scaled_weight']],
                               on='dept_id', how='left')[['scaled_weight']]
tr_w['level_5_sw'] = level_scaled_weight['scaled_weight'].values

del level, level_scaled_weight

######################### level 6 #######################################
level = wdf[wdf.Level_id == 'Level6']
# Set the name of the aggregation column to match 
# the column in our id columns
level.columns = ['Level_id', 'state_id', 'cat_id', 'scaled_weight']
level_scaled_weight = pd.merge(tr_w[['state_id', 'cat_id']], level[['state_id', 'cat_id', 'scaled_weight']],
                               on=['state_id', 'cat_id'], how='left')[['scaled_weight']]
tr_w['level_6_sw'] = level_scaled_weight['scaled_weight'].values

del level, level_scaled_weight

######################### level 7 #######################################
level = wdf[wdf.Level_id == 'Level7']
# Set the name of the aggregation column to match 
# the column in our id columns
level.columns = ['Level_id', 'state_id', 'dept_id', 'scaled_weight']
level_scaled_weight = pd.merge(tr_w[['state_id', 'dept_id']], level[['state_id', 'dept_id', 'scaled_weight']],
                               on=['state_id', 'dept_id'], how='left')[['scaled_weight']]
tr_w['level_7_sw'] = level_scaled_weight['scaled_weight'].values

del level, level_scaled_weight

######################### level 8 #######################################
level = wdf[wdf.Level_id == 'Level8']
# Set the name of the aggregation column to match 
# the column in our id columns
level.columns = ['Level_id', 'store_id', 'cat_id', 'scaled_weight']
level_scaled_weight = pd.merge(tr_w[['store_id', 'cat_id']], level[['store_id', 'cat_id', 'scaled_weight']],
                               on=['store_id', 'cat_id'], how='left')[['scaled_weight']]
tr_w['level_8_sw'] = level_scaled_weight['scaled_weight'].values

del level, level_scaled_weight

######################### level 9 #######################################
level = wdf[wdf.Level_id == 'Level9']
# Set the name of the aggregation column to match 
# the column in our id columns
level.columns = ['Level_id', 'store_id', 'dept_id', 'scaled_weight']
level_scaled_weight = pd.merge(tr_w[['store_id', 'dept_id']], level[['store_id', 'dept_id', 'scaled_weight']],
                               on=['store_id', 'dept_id'], how='left')[['scaled_weight']]
tr_w['level_9_sw'] = level_scaled_weight['scaled_weight'].values

del level, level_scaled_weight

######################### level 10 #######################################
level = wdf[wdf.Level_id == 'Level10']
# Set the name of the aggregation column to match 
# the column in our id columns
level.columns = ['Level_id', 'item_id', 'dept_id', 'scaled_weight']
level_scaled_weight = pd.merge(tr_w[['item_id']], level[['item_id', 'scaled_weight']],
                               on=['item_id'], how='left')[['scaled_weight']]
tr_w['level_10_sw'] = level_scaled_weight['scaled_weight'].values

del level, level_scaled_weight

######################### level 11 #######################################
level = wdf[wdf.Level_id == 'Level11']
# Set the name of the aggregation column to match 
# the column in our id columns
level.columns = ['Level_id', 'state_id', 'item_id', 'scaled_weight']
level_scaled_weight = pd.merge(tr_w[['state_id', 'item_id']], level[['state_id', 'item_id', 'scaled_weight']],
                               on=['state_id', 'item_id'], how='left')[['scaled_weight']]
tr_w['level_11_sw'] = level_scaled_weight['scaled_weight'].values

del level, level_scaled_weight

######################### level 12 #######################################
level = wdf[wdf.Level_id == 'Level12']
# Set the name of the aggregation column to match 
# the column in our id columns
level.columns = ['Level_id', 'item_id', 'store_id', 'scaled_weight']
level_scaled_weight = pd.merge(tr_w[['item_id', 'store_id']], level[['item_id', 'store_id', 'scaled_weight']],
                               on=['item_id', 'store_id'], how='left')[['scaled_weight']]
tr_w['level_12_sw'] = level_scaled_weight['scaled_weight'].values

del level, level_scaled_weight, wdf
gc.collect()

cols = [col for col in tr_w.columns if 'level' in col]
tr_w = tr_w[cols]

# %%
tr_x.head(10)
# Out:
#                               id        item_id    dept_id   cat_id store_id  \
# 0  HOBBIES_1_001_CA_1_validation  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1
# 1  HOBBIES_1_002_CA_1_validation  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1
# 2  HOBBIES_1_003_CA_1_validation  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1
# 3  HOBBIES_1_004_CA_1_validation  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1
# 4  HOBBIES_1_005_CA_1_validation  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1
# 5  HOBBIES_1_006_CA_1_validation  HOBBIES_1_006  HOBBIES_1  HOBBIES     CA_1
# 6  HOBBIES_1_007_CA_1_validation  HOBBIES_1_007  HOBBIES_1  HOBBIES     CA_1
# 7  HOBBIES_1_008_CA_1_validation  HOBBIES_1_008  HOBBIES_1  HOBBIES     CA_1
# 8  HOBBIES_1_009_CA_1_validation  HOBBIES_1_009  HOBBIES_1  HOBBIES     CA_1
# 9  HOBBIES_1_010_CA_1_validation  HOBBIES_1_010  HOBBIES_1  HOBBIES     CA_1
#
#   state_id     d  sales  release  sell_price  ...  snap_CA  snap_TX  snap_WI  \
# 0       CA  1796    2.0      224    8.257812  ...        0        0        0
# 1       CA  1796    0.0       20    3.970703  ...        0        0        0
# 2       CA  1796    3.0      300    2.970703  ...        0        0        0
# 3       CA  1796    0.0        5    4.640625  ...        0        0        0
# 4       CA  1796    0.0       16    2.880859  ...        0        0        0
# 5       CA  1796    0.0      109    0.959961  ...        0        0        0
# 6       CA  1796    0.0      123    7.878906  ...        0        0        0
# 7       CA  1796    2.0        0    0.479980  ...        0        0        0
# 8       CA  1796    0.0        0    1.769531  ...        0        0        0
# 9       CA  1796    2.0        0    2.970703  ...        0        0        0
#
#    tm_d  tm_w  tm_m  tm_y  tm_wm  tm_dw  tm_w_end
# 0    29    53    12     4      5      1         0
# 1    29    53    12     4      5      1         0
# 2    29    53    12     4      5      1         0
# 3    29    53    12     4      5      1         0
# 4    29    53    12     4      5      1         0
# 5    29    53    12     4      5      1         0
# 6    29    53    12     4      5      1         0
# 7    29    53    12     4      5      1         0
# 8    29    53    12     4      5      1         0
# 9    29    53    12     4      5      1         0
#
# [10 rows x 34 columns]

# %%
#Don't run this cell, it will crash the kernel 

roll_1 = csr_matrix(pd.get_dummies(tr_x.d, drop_first=False).values)

roll_2 = csr_matrix(pd.get_dummies(tr_x.d.astype('str') + tr_x.state_id.astype('str'),
                                  drop_first=False).values)

roll_3 = csr_matrix(pd.get_dummies(tr_x.d.astype('str') + tr_x.store_id.astype('str'),
                                   drop_first=False).values)

roll_4 = csr_matrix(pd.get_dummies(tr_x.d.astype('str') + tr_x.cat_id.astype('str'),
                                    drop_first=False).values)

roll_5 = csr_matrix(pd.get_dummies(tr_x.d.astype('str') + tr_x.dept_id.astype('str'),
                                    drop_first=False).values)

roll_6 = csr_matrix(pd.get_dummies(tr_x.d.astype('str') + tr_x.state_id.astype('str') + tr_x.cat_id.astype('str') ,
                                    drop_first=False).values)

roll_7 = csr_matrix(pd.get_dummies(tr_x.d.astype('str') + tr_x.state_id.astype('str') + tr_x.dept_id.astype('str'),
                                    drop_first=False).values)

roll_8 = csr_matrix(pd.get_dummies(tr_x.d.astype('str') + tr_x.store_id.astype('str') + tr_x.cat_id.astype('str'),
                                    drop_first=False).values)

roll_9 = csr_matrix(pd.get_dummies(tr_x.d.astype('str') + tr_x.store_id.astype('str') + tr_x.dept_id.astype('str'),
                                    drop_first=False).values)

roll_10 = csr_matrix(pd.get_dummies(tr_x.d.astype('str') + tr_x.item_id.astype('str') + tr_x.dept_id.astype('str'),
                                   drop_first=False).values)

roll_11 = csr_matrix(pd.get_dummies(tr_x.d.astype('str') + tr_x.state_id.astype('str') + tr_x.item_id.astype('str'),
                                    drop_first=False).values)

roll_12 = csr_matrix(pd.get_dummies(tr_x.d.astype('str') + tr_x.item_id.astype('str') + tr_x.store_id.astype('str'),
                                    drop_first=False).values)

# %%
roll_1 = csr_matrix(pd.get_dummies(tr_x.d, drop_first=False).values)

roll_2 = csr_matrix(pd.get_dummies(tr_x.d.astype('str') + tr_x.state_id.astype('str'),
                                  drop_first=False).values)

# %%
def gradient(roll, level_sw, actuals, preds):
    diff = actuals - preds
    
    
    
    
    
    
    
    
    
    
    return level_grad

# %%
import sklearn.metrics as metrics 
from datetime import datetime, timedelta
from sklearn.model_selection import GroupKFold
import lightgbm as lgb

def run_lgb(data, features, cat_features):
    
    # reset_index
    data.reset_index(inplace = True, drop = True)
    
    # going to evaluate with the last 28 days
    x_train = data[data['date'] <= '2016-04-24']
    y_train = x_train['demand']
    test = data[data['date'] >= '2016-04-25']

    # define random hyperparammeters
    params = {
        'boosting_type': 'gbdt',
        'n_jobs': -1,
        'seed': 42,
        'learning_rate': 0.09,
        'bagging_fraction': 0.85,
        'bagging_freq': 1, 
        'colsample_bytree': 0.85,
        'colsample_bynode': 0.85,
        'min_data_per_leaf': 25,
        'num_leaves': 200,
        'lambda_l1': 0.4,
        'lambda_l2': 0.4}
    
    oof = np.zeros(len(x_train))
    preds = np.zeros(len(test))
    
    # GroupKFold by week, month to avoid leakage and overfitting 
    kf = GroupKFold(6)
    
    # get subgroups for each week, year pair
    group = x_train['week'].astype(str) + '_' + x_train['year'].astype(str)
    for fold, (trn_idx, val_idx) in enumerate(kf.split(x_train, y_train, group)):
        print(f'Training fold {fold + 1}')
        train_set = lgb.Dataset(x_train.iloc[trn_idx][features], y_train.iloc[trn_idx], 
                                categorical_feature = cat_features)
        val_set = lgb.Dataset(x_train.iloc[val_idx][features], y_train.iloc[val_idx], 
                              categorical_feature = cat_features)
        
        # train with custom loss function and evaluation metric
        model = lgb.train(params, train_set, num_boost_round = 10000, early_stopping_rounds = 50, 
                          valid_sets = [train_set, val_set], verbose_eval = 20, fobj = custom_asymmetric_train, 
                          feval = custom_asymmetric_valid)
    
        model.save_model("LightGBM_CV.lgb")
        
        # predict oof
        oof[val_idx] = model.predict(x_train.iloc[val_idx][features])

        # predict test
        preds += model.predict(test[features]) / 6
        
        print('-'*50)
        print('\n')
        
    oof_rmse = np.sqrt(metrics.mean_squared_error(y_train, oof))
    print(f'Our out of folds rmse is {oof_rmse}')
        
    test = test[['id', 'date', 'demand']]
    test['demand'] = preds
    return test
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/lightgbm/__init__.py:48: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
def submit(test, submission):
    predictions = test[['id', 'date', 'demand']]
    predictions = pd.pivot(predictions, index = 'id', columns = 'date', values = 'demand').reset_index()
    predictions.columns = ['id'] + ['F' + str(i + 1) for i in range(28)]

    evaluation_rows = [row for row in submission['id'] if 'evaluation' in row] 
    evaluation = submission[submission['id'].isin(evaluation_rows)]

    validation = submission[['id']].merge(predictions, on = 'id')
    final = pd.concat([validation, evaluation])
    final.to_csv('May3rdsub.csv', index = False)

# %%
data.head()
# Out:
#                                 id          item_id      dept_id     cat_id  \
# 0  HOUSEHOLD_1_478_CA_4_validation  HOUSEHOLD_1_478  HOUSEHOLD_1  HOUSEHOLD
# 1  HOUSEHOLD_1_479_CA_4_validation  HOUSEHOLD_1_479  HOUSEHOLD_1  HOUSEHOLD
# 2  HOUSEHOLD_1_480_CA_4_validation  HOUSEHOLD_1_480  HOUSEHOLD_1  HOUSEHOLD
# 3  HOUSEHOLD_1_481_CA_4_validation  HOUSEHOLD_1_481  HOUSEHOLD_1  HOUSEHOLD
# 4  HOUSEHOLD_1_482_CA_4_validation  HOUSEHOLD_1_482  HOUSEHOLD_1  HOUSEHOLD
#
#   store_id state_id  demand   part        date  wm_yr_wk event_name_1  \
# 0     CA_4       CA       0  train  2013-08-04     11328          NaN
# 1     CA_4       CA       0  train  2013-08-04     11328          NaN
# 2     CA_4       CA       0  train  2013-08-04     11328          NaN
# 3     CA_4       CA       0  train  2013-08-04     11328          NaN
# 4     CA_4       CA       1  train  2013-08-04     11328          NaN
#
#   event_type_1 event_name_2 event_type_2  snap_CA  snap_TX  snap_WI  \
# 0          NaN          NaN          NaN        1        0        0
# 1          NaN          NaN          NaN        1        0        0
# 2          NaN          NaN          NaN        1        0        0
# 3          NaN          NaN          NaN        1        0        0
# 4          NaN          NaN          NaN        1        0        0
#
#    sell_price
# 0    2.669922
# 1    7.519531
# 2         NaN
# 3    4.968750
# 4    3.380859

# %%
data = transform(data)
# Out:
# Mem. usage decreased to 1516.57 Mb (57.1% reduction)

# %%
data = lag_features(data)
# Out:
# Mem. usage decreased to 1011.04 Mb (58.5% reduction)

# %%
features = ['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'event_name_1', 'event_type_1', 'event_name_2', 
            'event_type_2', 'snap_CA', 'snap_TX', 'snap_WI', 'sell_price', 'year', 
                'month', 'quarter', 'week', 'day', 'dayofweek', 'dayofyear', 'demand_rolling_mean_t7', 
            'demand_rolling_mean_t14', 'demand_rolling_mean_t28', 'demand_rolling_mean_t84',
                'demand_rolling_std_t7', 'demand_rolling_std_t14', 'demand_rolling_std_t28', 'demand_rolling_std_t84']
    
cat_features = ['item_id', 'dept_id', 'cat_id', 'store_id', 'state_id', 'event_name_1', 'event_type_1', 
                    'event_name_2', 'event_type_2']

# %%
data.head()
# Out:
#                                 id  item_id  dept_id  cat_id  store_id  \
# 0  HOUSEHOLD_1_478_CA_4_validation     2470        5       2         3
# 1  HOUSEHOLD_1_479_CA_4_validation     2471        5       2         3
# 2  HOUSEHOLD_1_480_CA_4_validation     2472        5       2         3
# 3  HOUSEHOLD_1_481_CA_4_validation     2473        5       2         3
# 4  HOUSEHOLD_1_482_CA_4_validation     2474        5       2         3
#
#    state_id  demand   part       date  wm_yr_wk  ...  dayofweek  dayofyear  \
# 0         0       0  train 2013-08-04     11328  ...          6        216
# 1         0       0  train 2013-08-04     11328  ...          6        216
# 2         0       0  train 2013-08-04     11328  ...          6        216
# 3         0       0  train 2013-08-04     11328  ...          6        216
# 4         0       1  train 2013-08-04     11328  ...          6        216
#
#    demand_rolling_mean_t7  demand_rolling_std_t7  demand_rolling_mean_t14  \
# 0                     NaN                    NaN                      NaN
# 1                     NaN                    NaN                      NaN
# 2                     NaN                    NaN                      NaN
# 3                     NaN                    NaN                      NaN
# 4                     NaN                    NaN                      NaN
#
#    demand_rolling_std_t14  demand_rolling_mean_t28  demand_rolling_std_t28  \
# 0                     NaN                      NaN                     NaN
# 1                     NaN                      NaN                     NaN
# 2                     NaN                      NaN                     NaN
# 3                     NaN                      NaN                     NaN
# 4                     NaN                      NaN                     NaN
#
#    demand_rolling_mean_t84  demand_rolling_std_t84
# 0                      NaN                     NaN
# 1                      NaN                     NaN
# 2                      NaN                     NaN
# 3                      NaN                     NaN
# 4                      NaN                     NaN
#
# [5 rows x 33 columns]

# %%
data = data[(data['date'] > '2013-11-23')]

# %%
data.head()
# Out:
#                                     id  item_id  dept_id  cat_id  store_id  \
# 3404700  HOBBIES_1_001_CA_1_validation     1437        3       1         0
# 3404701  HOBBIES_1_002_CA_1_validation     1438        3       1         0
# 3404702  HOBBIES_1_003_CA_1_validation     1439        3       1         0
# 3404703  HOBBIES_1_004_CA_1_validation     1440        3       1         0
# 3404704  HOBBIES_1_005_CA_1_validation     1441        3       1         0
#
#          state_id  demand   part       date  wm_yr_wk  ...  dayofweek  \
# 3404700         0       2  train 2013-11-24     11344  ...          6
# 3404701         0       0  train 2013-11-24     11344  ...          6
# 3404702         0       0  train 2013-11-24     11344  ...          6
# 3404703         0       3  train 2013-11-24     11344  ...          6
# 3404704         0       0  train 2013-11-24     11344  ...          6
#
#          dayofyear  demand_rolling_mean_t7  demand_rolling_std_t7  \
# 3404700        328                0.571289               0.976074
# 3404701        328                0.142822               0.377930
# 3404702        328                0.000000               0.000000
# 3404703        328                2.857422               2.968750
# 3404704        328                0.428467               0.534668
#
#          demand_rolling_mean_t14  demand_rolling_std_t14  \
# 3404700                 0.428467                0.755859
# 3404701                 0.071411                0.267334
# 3404702                 0.000000                0.000000
# 3404703                 2.427734                2.208984
# 3404704                 0.928711                0.997070
#
#          demand_rolling_mean_t28  demand_rolling_std_t28  \
# 3404700                 0.500000                0.693848
# 3404701                 0.178589                0.390137
# 3404702                 0.000000                0.000000
# 3404703                 2.177734                2.074219
# 3404704                 0.928711                1.120117
#
#          demand_rolling_mean_t84  demand_rolling_std_t84
# 3404700                 0.440430                0.646484
# 3404701                 0.214233                0.440918
# 3404702                 0.000000                0.000000
# 3404703                 1.845703                1.820312
# 3404704                 1.190430                1.197266
#
# [5 rows x 33 columns]

# %%
def custom_asymmetric_train(y_pred, y_true):
    y_true = y_true.get_label()
    residual = (y_true - y_pred).astype("float")
    grad = np.where(residual < 0, -2 * residual, -2 * residual * 1.15)
    hess = np.where(residual < 0, 2, 2 * 1.15)
    return grad, hess

def custom_asymmetric_valid(y_pred, y_true):
    y_true = y_true.get_label()
    residual = (y_true - y_pred).astype("float")
    loss = np.where(residual < 0, (residual ** 2) , (residual ** 2) * 1.15) 
    return "custom_asymmetric_eval", np.mean(loss), False

# %%
data.head()
# Out:
#                                     id  item_id  dept_id  cat_id  store_id  \
# 3404700  HOBBIES_1_001_CA_1_validation     1437        3       1         0
# 3404701  HOBBIES_1_002_CA_1_validation     1438        3       1         0
# 3404702  HOBBIES_1_003_CA_1_validation     1439        3       1         0
# 3404703  HOBBIES_1_004_CA_1_validation     1440        3       1         0
# 3404704  HOBBIES_1_005_CA_1_validation     1441        3       1         0
#
#          state_id  demand   part       date  wm_yr_wk  ...  dayofweek  \
# 3404700         0       2  train 2013-11-24     11344  ...          6
# 3404701         0       0  train 2013-11-24     11344  ...          6
# 3404702         0       0  train 2013-11-24     11344  ...          6
# 3404703         0       3  train 2013-11-24     11344  ...          6
# 3404704         0       0  train 2013-11-24     11344  ...          6
#
#          dayofyear  demand_rolling_mean_t7  demand_rolling_std_t7  \
# 3404700        328                0.571289               0.976074
# 3404701        328                0.142822               0.377930
# 3404702        328                0.000000               0.000000
# 3404703        328                2.857422               2.968750
# 3404704        328                0.428467               0.534668
#
#          demand_rolling_mean_t14  demand_rolling_std_t14  \
# 3404700                 0.428467                0.755859
# 3404701                 0.071411                0.267334
# 3404702                 0.000000                0.000000
# 3404703                 2.427734                2.208984
# 3404704                 0.928711                0.997070
#
#          demand_rolling_mean_t28  demand_rolling_std_t28  \
# 3404700                 0.500000                0.693848
# 3404701                 0.178589                0.390137
# 3404702                 0.000000                0.000000
# 3404703                 2.177734                2.074219
# 3404704                 0.928711                1.120117
#
#          demand_rolling_mean_t84  demand_rolling_std_t84
# 3404700                 0.440430                0.646484
# 3404701                 0.214233                0.440918
# 3404702                 0.000000                0.000000
# 3404703                 1.845703                1.820312
# 3404704                 1.190430                1.197266
#
# [5 rows x 33 columns]

# %%
data = reduce_mem_usage(data)
# Out:
# Mem. usage decreased to 2013.21 Mb (6.2% reduction)

# %%
import gc

gc.collect()
# Out:
# 85

# %%
next_test = run_lgb(data, features, cat_features)
predict(next_test, submission)
# Out:
# Training fold 1
# /opt/anaconda3/lib/python3.7/site-packages/lightgbm/basic.py:1243: UserWarning: Using categorical_feature in Dataset.
#   warnings.warn('Using categorical_feature in Dataset.')
# Training until validation scores don't improve for 50 rounds
# [20]	training's custom_asymmetric_eval: 5.87134	valid_1's custom_asymmetric_eval: 6.7437
# [40]	training's custom_asymmetric_eval: 5.23556	valid_1's custom_asymmetric_eval: 6.30753
# [60]	training's custom_asymmetric_eval: 4.97802	valid_1's custom_asymmetric_eval: 6.15907
# [80]	training's custom_asymmetric_eval: 4.81548	valid_1's custom_asymmetric_eval: 6.08807
# [100]	training's custom_asymmetric_eval: 4.68931	valid_1's custom_asymmetric_eval: 6.04015
# [120]	training's custom_asymmetric_eval: 4.58931	valid_1's custom_asymmetric_eval: 5.99745
# [140]	training's custom_asymmetric_eval: 4.50894	valid_1's custom_asymmetric_eval: 5.96923
# [160]	training's custom_asymmetric_eval: 4.43473	valid_1's custom_asymmetric_eval: 5.94807
# [180]	training's custom_asymmetric_eval: 4.37263	valid_1's custom_asymmetric_eval: 5.93221
# [200]	training's custom_asymmetric_eval: 4.31884	valid_1's custom_asymmetric_eval: 5.91292
# [220]	training's custom_asymmetric_eval: 4.27268	valid_1's custom_asymmetric_eval: 5.90098
# [240]	training's custom_asymmetric_eval: 4.23	valid_1's custom_asymmetric_eval: 5.89601
# [260]	training's custom_asymmetric_eval: 4.18725	valid_1's custom_asymmetric_eval: 5.88649
# [280]	training's custom_asymmetric_eval: 4.15305	valid_1's custom_asymmetric_eval: 5.87862
# [300]	training's custom_asymmetric_eval: 4.11571	valid_1's custom_asymmetric_eval: 5.87223
# [320]	training's custom_asymmetric_eval: 4.0793	valid_1's custom_asymmetric_eval: 5.86828
# [340]	training's custom_asymmetric_eval: 4.04807	valid_1's custom_asymmetric_eval: 5.85868
# [360]	training's custom_asymmetric_eval: 4.01667	valid_1's custom_asymmetric_eval: 5.85029
# [380]	training's custom_asymmetric_eval: 3.98658	valid_1's custom_asymmetric_eval: 5.84549
# [400]	training's custom_asymmetric_eval: 3.95945	valid_1's custom_asymmetric_eval: 5.83891
# [420]	training's custom_asymmetric_eval: 3.93386	valid_1's custom_asymmetric_eval: 5.83588
# [440]	training's custom_asymmetric_eval: 3.90783	valid_1's custom_asymmetric_eval: 5.8291
# [460]	training's custom_asymmetric_eval: 3.8834	valid_1's custom_asymmetric_eval: 5.82658
# [480]	training's custom_asymmetric_eval: 3.85987	valid_1's custom_asymmetric_eval: 5.82402
# [500]	training's custom_asymmetric_eval: 3.83572	valid_1's custom_asymmetric_eval: 5.81516
# [520]	training's custom_asymmetric_eval: 3.81282	valid_1's custom_asymmetric_eval: 5.81056
# [540]	training's custom_asymmetric_eval: 3.79071	valid_1's custom_asymmetric_eval: 5.80543
# [560]	training's custom_asymmetric_eval: 3.77035	valid_1's custom_asymmetric_eval: 5.79765
# [580]	training's custom_asymmetric_eval: 3.75061	valid_1's custom_asymmetric_eval: 5.79494
# [600]	training's custom_asymmetric_eval: 3.73235	valid_1's custom_asymmetric_eval: 5.79402
# [620]	training's custom_asymmetric_eval: 3.71392	valid_1's custom_asymmetric_eval: 5.79045
# [640]	training's custom_asymmetric_eval: 3.69569	valid_1's custom_asymmetric_eval: 5.78925
# [660]	training's custom_asymmetric_eval: 3.67807	valid_1's custom_asymmetric_eval: 5.78846
# [680]	training's custom_asymmetric_eval: 3.66006	valid_1's custom_asymmetric_eval: 5.7839
# [700]	training's custom_asymmetric_eval: 3.64241	valid_1's custom_asymmetric_eval: 5.77866
# [720]	training's custom_asymmetric_eval: 3.62555	valid_1's custom_asymmetric_eval: 5.77606
# [740]	training's custom_asymmetric_eval: 3.60876	valid_1's custom_asymmetric_eval: 5.77654
# [760]	training's custom_asymmetric_eval: 3.5927	valid_1's custom_asymmetric_eval: 5.77553
# [780]	training's custom_asymmetric_eval: 3.57671	valid_1's custom_asymmetric_eval: 5.77437
# [800]	training's custom_asymmetric_eval: 3.56176	valid_1's custom_asymmetric_eval: 5.77152
# [820]	training's custom_asymmetric_eval: 3.54628	valid_1's custom_asymmetric_eval: 5.76925
# [840]	training's custom_asymmetric_eval: 3.53033	valid_1's custom_asymmetric_eval: 5.76385
# [860]	training's custom_asymmetric_eval: 3.51582	valid_1's custom_asymmetric_eval: 5.76306
# [880]	training's custom_asymmetric_eval: 3.50105	valid_1's custom_asymmetric_eval: 5.76065
# [900]	training's custom_asymmetric_eval: 3.48724	valid_1's custom_asymmetric_eval: 5.75811
# [920]	training's custom_asymmetric_eval: 3.47459	valid_1's custom_asymmetric_eval: 5.75644
# [940]	training's custom_asymmetric_eval: 3.46166	valid_1's custom_asymmetric_eval: 5.75427
# [960]	training's custom_asymmetric_eval: 3.44851	valid_1's custom_asymmetric_eval: 5.75289
# [980]	training's custom_asymmetric_eval: 3.43534	valid_1's custom_asymmetric_eval: 5.75141
# [1000]	training's custom_asymmetric_eval: 3.42347	valid_1's custom_asymmetric_eval: 5.74927
# [1020]	training's custom_asymmetric_eval: 3.41192	valid_1's custom_asymmetric_eval: 5.74576
# [1040]	training's custom_asymmetric_eval: 3.39964	valid_1's custom_asymmetric_eval: 5.74502
# [1060]	training's custom_asymmetric_eval: 3.38757	valid_1's custom_asymmetric_eval: 5.74337
# [1080]	training's custom_asymmetric_eval: 3.37692	valid_1's custom_asymmetric_eval: 5.74176
# [1100]	training's custom_asymmetric_eval: 3.36551	valid_1's custom_asymmetric_eval: 5.7413
# [1120]	training's custom_asymmetric_eval: 3.35393	valid_1's custom_asymmetric_eval: 5.73761
# [1140]	training's custom_asymmetric_eval: 3.34275	valid_1's custom_asymmetric_eval: 5.73557
# [1160]	training's custom_asymmetric_eval: 3.33236	valid_1's custom_asymmetric_eval: 5.73501
# [1180]	training's custom_asymmetric_eval: 3.3215	valid_1's custom_asymmetric_eval: 5.73361
# [1200]	training's custom_asymmetric_eval: 3.31079	valid_1's custom_asymmetric_eval: 5.73254
# [1220]	training's custom_asymmetric_eval: 3.30021	valid_1's custom_asymmetric_eval: 5.73228
# [1240]	training's custom_asymmetric_eval: 3.28975	valid_1's custom_asymmetric_eval: 5.7318
# [1260]	training's custom_asymmetric_eval: 3.28031	valid_1's custom_asymmetric_eval: 5.73073
# [1280]	training's custom_asymmetric_eval: 3.27045	valid_1's custom_asymmetric_eval: 5.73084
# [1300]	training's custom_asymmetric_eval: 3.26095	valid_1's custom_asymmetric_eval: 5.72903
# [1320]	training's custom_asymmetric_eval: 3.25138	valid_1's custom_asymmetric_eval: 5.72721
# [1340]	training's custom_asymmetric_eval: 3.24187	valid_1's custom_asymmetric_eval: 5.72815
# [1360]	training's custom_asymmetric_eval: 3.23221	valid_1's custom_asymmetric_eval: 5.7268
# [1380]	training's custom_asymmetric_eval: 3.22271	valid_1's custom_asymmetric_eval: 5.72705
# [1400]	training's custom_asymmetric_eval: 3.21298	valid_1's custom_asymmetric_eval: 5.72621
# [1420]	training's custom_asymmetric_eval: 3.20406	valid_1's custom_asymmetric_eval: 5.72447
# [1440]	training's custom_asymmetric_eval: 3.19492	valid_1's custom_asymmetric_eval: 5.72223
# [1460]	training's custom_asymmetric_eval: 3.18633	valid_1's custom_asymmetric_eval: 5.7219
# [1480]	training's custom_asymmetric_eval: 3.17763	valid_1's custom_asymmetric_eval: 5.72129
# [1500]	training's custom_asymmetric_eval: 3.16939	valid_1's custom_asymmetric_eval: 5.72002
# [1520]	training's custom_asymmetric_eval: 3.16048	valid_1's custom_asymmetric_eval: 5.71899
# [1540]	training's custom_asymmetric_eval: 3.15209	valid_1's custom_asymmetric_eval: 5.71722
# [1560]	training's custom_asymmetric_eval: 3.14464	valid_1's custom_asymmetric_eval: 5.71781
# [1580]	training's custom_asymmetric_eval: 3.13682	valid_1's custom_asymmetric_eval: 5.7185
# Early stopping, best iteration is:
# [1539]	training's custom_asymmetric_eval: 3.15243	valid_1's custom_asymmetric_eval: 5.71693
# --------------------------------------------------
#
#
# Training fold 2
# Training until validation scores don't improve for 50 rounds
# [20]	training's custom_asymmetric_eval: 6.04409	valid_1's custom_asymmetric_eval: 5.75357
# [40]	training's custom_asymmetric_eval: 5.38425	valid_1's custom_asymmetric_eval: 5.2793
# [60]	training's custom_asymmetric_eval: 5.10581	valid_1's custom_asymmetric_eval: 5.13364
# [80]	training's custom_asymmetric_eval: 4.93167	valid_1's custom_asymmetric_eval: 5.05028
# [100]	training's custom_asymmetric_eval: 4.78957	valid_1's custom_asymmetric_eval: 4.99755
# [120]	training's custom_asymmetric_eval: 4.6865	valid_1's custom_asymmetric_eval: 4.96945
# [140]	training's custom_asymmetric_eval: 4.60394	valid_1's custom_asymmetric_eval: 4.94781
# [160]	training's custom_asymmetric_eval: 4.5249	valid_1's custom_asymmetric_eval: 4.91754
# [180]	training's custom_asymmetric_eval: 4.46315	valid_1's custom_asymmetric_eval: 4.90091
# [200]	training's custom_asymmetric_eval: 4.40813	valid_1's custom_asymmetric_eval: 4.89171
# [220]	training's custom_asymmetric_eval: 4.35451	valid_1's custom_asymmetric_eval: 4.87773
# [240]	training's custom_asymmetric_eval: 4.30845	valid_1's custom_asymmetric_eval: 4.86502
# [260]	training's custom_asymmetric_eval: 4.26131	valid_1's custom_asymmetric_eval: 4.8516
# [280]	training's custom_asymmetric_eval: 4.21984	valid_1's custom_asymmetric_eval: 4.84294
# [300]	training's custom_asymmetric_eval: 4.17671	valid_1's custom_asymmetric_eval: 4.83109
# [320]	training's custom_asymmetric_eval: 4.13998	valid_1's custom_asymmetric_eval: 4.82272
# [340]	training's custom_asymmetric_eval: 4.10451	valid_1's custom_asymmetric_eval: 4.81517
# [360]	training's custom_asymmetric_eval: 4.07196	valid_1's custom_asymmetric_eval: 4.80782
# [380]	training's custom_asymmetric_eval: 4.04322	valid_1's custom_asymmetric_eval: 4.8035
# [400]	training's custom_asymmetric_eval: 4.01513	valid_1's custom_asymmetric_eval: 4.80009
# [420]	training's custom_asymmetric_eval: 3.98797	valid_1's custom_asymmetric_eval: 4.79734
# [440]	training's custom_asymmetric_eval: 3.96005	valid_1's custom_asymmetric_eval: 4.79192
# [460]	training's custom_asymmetric_eval: 3.9316	valid_1's custom_asymmetric_eval: 4.78429
# [480]	training's custom_asymmetric_eval: 3.90451	valid_1's custom_asymmetric_eval: 4.77995
# [500]	training's custom_asymmetric_eval: 3.88023	valid_1's custom_asymmetric_eval: 4.77673
# [520]	training's custom_asymmetric_eval: 3.85695	valid_1's custom_asymmetric_eval: 4.77138
# [540]	training's custom_asymmetric_eval: 3.83337	valid_1's custom_asymmetric_eval: 4.76817
# [560]	training's custom_asymmetric_eval: 3.81171	valid_1's custom_asymmetric_eval: 4.76675
# [580]	training's custom_asymmetric_eval: 3.79311	valid_1's custom_asymmetric_eval: 4.76325
# [600]	training's custom_asymmetric_eval: 3.773	valid_1's custom_asymmetric_eval: 4.76131
# [620]	training's custom_asymmetric_eval: 3.75288	valid_1's custom_asymmetric_eval: 4.75698
# [640]	training's custom_asymmetric_eval: 3.73516	valid_1's custom_asymmetric_eval: 4.75499
# [660]	training's custom_asymmetric_eval: 3.71728	valid_1's custom_asymmetric_eval: 4.75103
# [680]	training's custom_asymmetric_eval: 3.69914	valid_1's custom_asymmetric_eval: 4.74759
# [700]	training's custom_asymmetric_eval: 3.6813	valid_1's custom_asymmetric_eval: 4.74557
# [720]	training's custom_asymmetric_eval: 3.66381	valid_1's custom_asymmetric_eval: 4.7426
# [740]	training's custom_asymmetric_eval: 3.64458	valid_1's custom_asymmetric_eval: 4.73934
# [760]	training's custom_asymmetric_eval: 3.62796	valid_1's custom_asymmetric_eval: 4.73801
# [780]	training's custom_asymmetric_eval: 3.61151	valid_1's custom_asymmetric_eval: 4.7359
# [800]	training's custom_asymmetric_eval: 3.59582	valid_1's custom_asymmetric_eval: 4.73529
# [820]	training's custom_asymmetric_eval: 3.58096	valid_1's custom_asymmetric_eval: 4.73414
# [840]	training's custom_asymmetric_eval: 3.56632	valid_1's custom_asymmetric_eval: 4.73368
# [860]	training's custom_asymmetric_eval: 3.55183	valid_1's custom_asymmetric_eval: 4.73176
# [880]	training's custom_asymmetric_eval: 3.53845	valid_1's custom_asymmetric_eval: 4.73027
# [900]	training's custom_asymmetric_eval: 3.52498	valid_1's custom_asymmetric_eval: 4.72992
# [920]	training's custom_asymmetric_eval: 3.51141	valid_1's custom_asymmetric_eval: 4.728
# [940]	training's custom_asymmetric_eval: 3.49839	valid_1's custom_asymmetric_eval: 4.72667
# [960]	training's custom_asymmetric_eval: 3.485	valid_1's custom_asymmetric_eval: 4.7252
# [980]	training's custom_asymmetric_eval: 3.47231	valid_1's custom_asymmetric_eval: 4.72396
# [1000]	training's custom_asymmetric_eval: 3.45907	valid_1's custom_asymmetric_eval: 4.72204
# [1020]	training's custom_asymmetric_eval: 3.4456	valid_1's custom_asymmetric_eval: 4.71998
# [1040]	training's custom_asymmetric_eval: 3.43316	valid_1's custom_asymmetric_eval: 4.71839
# [1060]	training's custom_asymmetric_eval: 3.4208	valid_1's custom_asymmetric_eval: 4.71666
# [1080]	training's custom_asymmetric_eval: 3.40891	valid_1's custom_asymmetric_eval: 4.71532
# [1100]	training's custom_asymmetric_eval: 3.39686	valid_1's custom_asymmetric_eval: 4.71406
# [1120]	training's custom_asymmetric_eval: 3.38582	valid_1's custom_asymmetric_eval: 4.71329
# [1140]	training's custom_asymmetric_eval: 3.37453	valid_1's custom_asymmetric_eval: 4.71317
# [1160]	training's custom_asymmetric_eval: 3.36286	valid_1's custom_asymmetric_eval: 4.71053
# [1180]	training's custom_asymmetric_eval: 3.35264	valid_1's custom_asymmetric_eval: 4.70914
# [1200]	training's custom_asymmetric_eval: 3.34146	valid_1's custom_asymmetric_eval: 4.70757
# [1220]	training's custom_asymmetric_eval: 3.33041	valid_1's custom_asymmetric_eval: 4.70636
# [1240]	training's custom_asymmetric_eval: 3.31994	valid_1's custom_asymmetric_eval: 4.70719
# [1260]	training's custom_asymmetric_eval: 3.31009	valid_1's custom_asymmetric_eval: 4.7062
# [1280]	training's custom_asymmetric_eval: 3.29894	valid_1's custom_asymmetric_eval: 4.70344
# [1300]	training's custom_asymmetric_eval: 3.28837	valid_1's custom_asymmetric_eval: 4.70149
# [1320]	training's custom_asymmetric_eval: 3.2784	valid_1's custom_asymmetric_eval: 4.70044
# [1340]	training's custom_asymmetric_eval: 3.26879	valid_1's custom_asymmetric_eval: 4.69898
# [1360]	training's custom_asymmetric_eval: 3.25909	valid_1's custom_asymmetric_eval: 4.69706
# [1380]	training's custom_asymmetric_eval: 3.24981	valid_1's custom_asymmetric_eval: 4.69554
# [1400]	training's custom_asymmetric_eval: 3.24126	valid_1's custom_asymmetric_eval: 4.6955
# [1420]	training's custom_asymmetric_eval: 3.2325	valid_1's custom_asymmetric_eval: 4.69628
# [1440]	training's custom_asymmetric_eval: 3.22296	valid_1's custom_asymmetric_eval: 4.6949
# [1460]	training's custom_asymmetric_eval: 3.2125	valid_1's custom_asymmetric_eval: 4.69404
# [1480]	training's custom_asymmetric_eval: 3.20414	valid_1's custom_asymmetric_eval: 4.69382
# [1500]	training's custom_asymmetric_eval: 3.19544	valid_1's custom_asymmetric_eval: 4.692
# [1520]	training's custom_asymmetric_eval: 3.18639	valid_1's custom_asymmetric_eval: 4.69137
# [1540]	training's custom_asymmetric_eval: 3.17836	valid_1's custom_asymmetric_eval: 4.69103
# [1560]	training's custom_asymmetric_eval: 3.17045	valid_1's custom_asymmetric_eval: 4.69076
# [1580]	training's custom_asymmetric_eval: 3.16207	valid_1's custom_asymmetric_eval: 4.69017
# [1600]	training's custom_asymmetric_eval: 3.15348	valid_1's custom_asymmetric_eval: 4.68884
# [1620]	training's custom_asymmetric_eval: 3.14578	valid_1's custom_asymmetric_eval: 4.68898
# [1640]	training's custom_asymmetric_eval: 3.13779	valid_1's custom_asymmetric_eval: 4.68834
# [1660]	training's custom_asymmetric_eval: 3.12968	valid_1's custom_asymmetric_eval: 4.68855
# [1680]	training's custom_asymmetric_eval: 3.12178	valid_1's custom_asymmetric_eval: 4.6884
# [1700]	training's custom_asymmetric_eval: 3.11375	valid_1's custom_asymmetric_eval: 4.68818
# [1720]	training's custom_asymmetric_eval: 3.10501	valid_1's custom_asymmetric_eval: 4.68766
# [1740]	training's custom_asymmetric_eval: 3.09787	valid_1's custom_asymmetric_eval: 4.68714
# [1760]	training's custom_asymmetric_eval: 3.09051	valid_1's custom_asymmetric_eval: 4.68723
# [1780]	training's custom_asymmetric_eval: 3.08233	valid_1's custom_asymmetric_eval: 4.6867
# [1800]	training's custom_asymmetric_eval: 3.07446	valid_1's custom_asymmetric_eval: 4.6858
# [1820]	training's custom_asymmetric_eval: 3.06698	valid_1's custom_asymmetric_eval: 4.68529
# [1840]	training's custom_asymmetric_eval: 3.05894	valid_1's custom_asymmetric_eval: 4.6848
# [1860]	training's custom_asymmetric_eval: 3.05205	valid_1's custom_asymmetric_eval: 4.68465
# [1880]	training's custom_asymmetric_eval: 3.04524	valid_1's custom_asymmetric_eval: 4.68395
# [1900]	training's custom_asymmetric_eval: 3.03759	valid_1's custom_asymmetric_eval: 4.6821
# [1920]	training's custom_asymmetric_eval: 3.03068	valid_1's custom_asymmetric_eval: 4.6816
# [1940]	training's custom_asymmetric_eval: 3.02389	valid_1's custom_asymmetric_eval: 4.6818
# [1960]	training's custom_asymmetric_eval: 3.01714	valid_1's custom_asymmetric_eval: 4.6818
# [1980]	training's custom_asymmetric_eval: 3.01022	valid_1's custom_asymmetric_eval: 4.68072
# [2000]	training's custom_asymmetric_eval: 3.00375	valid_1's custom_asymmetric_eval: 4.67957
# [2020]	training's custom_asymmetric_eval: 2.99656	valid_1's custom_asymmetric_eval: 4.6791
# [2040]	training's custom_asymmetric_eval: 2.99016	valid_1's custom_asymmetric_eval: 4.67945
# [2060]	training's custom_asymmetric_eval: 2.98355	valid_1's custom_asymmetric_eval: 4.68015
# Early stopping, best iteration is:
# [2011]	training's custom_asymmetric_eval: 2.9995	valid_1's custom_asymmetric_eval: 4.67883
# --------------------------------------------------
#
#
# Training fold 3
# Training until validation scores don't improve for 50 rounds
# [20]	training's custom_asymmetric_eval: 5.97807	valid_1's custom_asymmetric_eval: 6.09021
# [40]	training's custom_asymmetric_eval: 5.3062	valid_1's custom_asymmetric_eval: 5.57096
# [60]	training's custom_asymmetric_eval: 5.03841	valid_1's custom_asymmetric_eval: 5.40656
# [80]	training's custom_asymmetric_eval: 4.87029	valid_1's custom_asymmetric_eval: 5.31842
# [100]	training's custom_asymmetric_eval: 4.73001	valid_1's custom_asymmetric_eval: 5.25152
# [120]	training's custom_asymmetric_eval: 4.63253	valid_1's custom_asymmetric_eval: 5.20914
# [140]	training's custom_asymmetric_eval: 4.55257	valid_1's custom_asymmetric_eval: 5.17889
# [160]	training's custom_asymmetric_eval: 4.48133	valid_1's custom_asymmetric_eval: 5.14535
# [180]	training's custom_asymmetric_eval: 4.42588	valid_1's custom_asymmetric_eval: 5.12829
# [200]	training's custom_asymmetric_eval: 4.37101	valid_1's custom_asymmetric_eval: 5.11047
# [220]	training's custom_asymmetric_eval: 4.31909	valid_1's custom_asymmetric_eval: 5.09306
# [240]	training's custom_asymmetric_eval: 4.27479	valid_1's custom_asymmetric_eval: 5.07851
# [260]	training's custom_asymmetric_eval: 4.2316	valid_1's custom_asymmetric_eval: 5.06284
# [280]	training's custom_asymmetric_eval: 4.19167	valid_1's custom_asymmetric_eval: 5.0515
# [300]	training's custom_asymmetric_eval: 4.1547	valid_1's custom_asymmetric_eval: 5.04226
# [320]	training's custom_asymmetric_eval: 4.11832	valid_1's custom_asymmetric_eval: 5.03073
# [340]	training's custom_asymmetric_eval: 4.08417	valid_1's custom_asymmetric_eval: 5.02336
# [360]	training's custom_asymmetric_eval: 4.05277	valid_1's custom_asymmetric_eval: 5.01585
# [380]	training's custom_asymmetric_eval: 4.02332	valid_1's custom_asymmetric_eval: 5.0089
# [400]	training's custom_asymmetric_eval: 3.99451	valid_1's custom_asymmetric_eval: 4.9995
# [420]	training's custom_asymmetric_eval: 3.96667	valid_1's custom_asymmetric_eval: 4.99124
# [440]	training's custom_asymmetric_eval: 3.93815	valid_1's custom_asymmetric_eval: 4.98274
# [460]	training's custom_asymmetric_eval: 3.91311	valid_1's custom_asymmetric_eval: 4.97557
# [480]	training's custom_asymmetric_eval: 3.88588	valid_1's custom_asymmetric_eval: 4.97047
# [500]	training's custom_asymmetric_eval: 3.86204	valid_1's custom_asymmetric_eval: 4.96517
# [520]	training's custom_asymmetric_eval: 3.83599	valid_1's custom_asymmetric_eval: 4.95816
# [540]	training's custom_asymmetric_eval: 3.81554	valid_1's custom_asymmetric_eval: 4.95229
# [560]	training's custom_asymmetric_eval: 3.794	valid_1's custom_asymmetric_eval: 4.9481
# [580]	training's custom_asymmetric_eval: 3.77325	valid_1's custom_asymmetric_eval: 4.94258
# [600]	training's custom_asymmetric_eval: 3.7535	valid_1's custom_asymmetric_eval: 4.93968
# [620]	training's custom_asymmetric_eval: 3.73349	valid_1's custom_asymmetric_eval: 4.93643
# [640]	training's custom_asymmetric_eval: 3.71578	valid_1's custom_asymmetric_eval: 4.93399
# [660]	training's custom_asymmetric_eval: 3.69837	valid_1's custom_asymmetric_eval: 4.92851
# [680]	training's custom_asymmetric_eval: 3.67958	valid_1's custom_asymmetric_eval: 4.92563
# [700]	training's custom_asymmetric_eval: 3.66141	valid_1's custom_asymmetric_eval: 4.92062
# [720]	training's custom_asymmetric_eval: 3.64432	valid_1's custom_asymmetric_eval: 4.91577
# [740]	training's custom_asymmetric_eval: 3.62726	valid_1's custom_asymmetric_eval: 4.91326
# [760]	training's custom_asymmetric_eval: 3.61169	valid_1's custom_asymmetric_eval: 4.9106
# [780]	training's custom_asymmetric_eval: 3.59506	valid_1's custom_asymmetric_eval: 4.90541
# [800]	training's custom_asymmetric_eval: 3.57881	valid_1's custom_asymmetric_eval: 4.90161
# [820]	training's custom_asymmetric_eval: 3.56346	valid_1's custom_asymmetric_eval: 4.89926
# [840]	training's custom_asymmetric_eval: 3.54958	valid_1's custom_asymmetric_eval: 4.89784
# [860]	training's custom_asymmetric_eval: 3.53523	valid_1's custom_asymmetric_eval: 4.89492
# [880]	training's custom_asymmetric_eval: 3.5202	valid_1's custom_asymmetric_eval: 4.89168
# [900]	training's custom_asymmetric_eval: 3.5073	valid_1's custom_asymmetric_eval: 4.88969
# [920]	training's custom_asymmetric_eval: 3.49467	valid_1's custom_asymmetric_eval: 4.88877
# [940]	training's custom_asymmetric_eval: 3.48159	valid_1's custom_asymmetric_eval: 4.88594
# [960]	training's custom_asymmetric_eval: 3.46777	valid_1's custom_asymmetric_eval: 4.88239
# [980]	training's custom_asymmetric_eval: 3.45567	valid_1's custom_asymmetric_eval: 4.88005
# [1000]	training's custom_asymmetric_eval: 3.44318	valid_1's custom_asymmetric_eval: 4.87861
# [1020]	training's custom_asymmetric_eval: 3.43039	valid_1's custom_asymmetric_eval: 4.87718
# [1040]	training's custom_asymmetric_eval: 3.41825	valid_1's custom_asymmetric_eval: 4.87586
# [1060]	training's custom_asymmetric_eval: 3.40704	valid_1's custom_asymmetric_eval: 4.87446
# [1080]	training's custom_asymmetric_eval: 3.39451	valid_1's custom_asymmetric_eval: 4.87183
# [1100]	training's custom_asymmetric_eval: 3.38327	valid_1's custom_asymmetric_eval: 4.87039
# [1120]	training's custom_asymmetric_eval: 3.37141	valid_1's custom_asymmetric_eval: 4.86732
# [1140]	training's custom_asymmetric_eval: 3.36048	valid_1's custom_asymmetric_eval: 4.86658
# [1160]	training's custom_asymmetric_eval: 3.34901	valid_1's custom_asymmetric_eval: 4.86388
# [1180]	training's custom_asymmetric_eval: 3.33749	valid_1's custom_asymmetric_eval: 4.86102
# [1200]	training's custom_asymmetric_eval: 3.32648	valid_1's custom_asymmetric_eval: 4.86133
# [1220]	training's custom_asymmetric_eval: 3.31633	valid_1's custom_asymmetric_eval: 4.85942
# [1240]	training's custom_asymmetric_eval: 3.30606	valid_1's custom_asymmetric_eval: 4.85792
# [1260]	training's custom_asymmetric_eval: 3.29569	valid_1's custom_asymmetric_eval: 4.85704
# [1280]	training's custom_asymmetric_eval: 3.28622	valid_1's custom_asymmetric_eval: 4.85588
# [1300]	training's custom_asymmetric_eval: 3.27613	valid_1's custom_asymmetric_eval: 4.85493
# [1320]	training's custom_asymmetric_eval: 3.26606	valid_1's custom_asymmetric_eval: 4.8537
# [1340]	training's custom_asymmetric_eval: 3.25625	valid_1's custom_asymmetric_eval: 4.85305
# [1360]	training's custom_asymmetric_eval: 3.24654	valid_1's custom_asymmetric_eval: 4.85167
# [1380]	training's custom_asymmetric_eval: 3.23657	valid_1's custom_asymmetric_eval: 4.85011
# [1400]	training's custom_asymmetric_eval: 3.22667	valid_1's custom_asymmetric_eval: 4.84708
# [1420]	training's custom_asymmetric_eval: 3.21795	valid_1's custom_asymmetric_eval: 4.846
# [1440]	training's custom_asymmetric_eval: 3.20877	valid_1's custom_asymmetric_eval: 4.8451
# [1460]	training's custom_asymmetric_eval: 3.20009	valid_1's custom_asymmetric_eval: 4.84412
# [1480]	training's custom_asymmetric_eval: 3.19144	valid_1's custom_asymmetric_eval: 4.84188
# [1500]	training's custom_asymmetric_eval: 3.18316	valid_1's custom_asymmetric_eval: 4.84089
# [1520]	training's custom_asymmetric_eval: 3.17439	valid_1's custom_asymmetric_eval: 4.83961
# [1540]	training's custom_asymmetric_eval: 3.16582	valid_1's custom_asymmetric_eval: 4.8379
# [1560]	training's custom_asymmetric_eval: 3.1578	valid_1's custom_asymmetric_eval: 4.83669
# [1580]	training's custom_asymmetric_eval: 3.14918	valid_1's custom_asymmetric_eval: 4.83511
# [1600]	training's custom_asymmetric_eval: 3.13942	valid_1's custom_asymmetric_eval: 4.83293
# [1620]	training's custom_asymmetric_eval: 3.1315	valid_1's custom_asymmetric_eval: 4.83241
# [1640]	training's custom_asymmetric_eval: 3.12315	valid_1's custom_asymmetric_eval: 4.83131
# [1660]	training's custom_asymmetric_eval: 3.11525	valid_1's custom_asymmetric_eval: 4.83041
# [1680]	training's custom_asymmetric_eval: 3.10722	valid_1's custom_asymmetric_eval: 4.82947
# [1700]	training's custom_asymmetric_eval: 3.09932	valid_1's custom_asymmetric_eval: 4.82799
# [1720]	training's custom_asymmetric_eval: 3.09191	valid_1's custom_asymmetric_eval: 4.82743
# [1740]	training's custom_asymmetric_eval: 3.08405	valid_1's custom_asymmetric_eval: 4.82646
# [1760]	training's custom_asymmetric_eval: 3.07689	valid_1's custom_asymmetric_eval: 4.82571
# [1780]	training's custom_asymmetric_eval: 3.06939	valid_1's custom_asymmetric_eval: 4.82596
# [1800]	training's custom_asymmetric_eval: 3.06181	valid_1's custom_asymmetric_eval: 4.82535
# [1820]	training's custom_asymmetric_eval: 3.05475	valid_1's custom_asymmetric_eval: 4.82464
# [1840]	training's custom_asymmetric_eval: 3.04704	valid_1's custom_asymmetric_eval: 4.82305
# [1860]	training's custom_asymmetric_eval: 3.04001	valid_1's custom_asymmetric_eval: 4.82204
# [1880]	training's custom_asymmetric_eval: 3.0332	valid_1's custom_asymmetric_eval: 4.8216
# [1900]	training's custom_asymmetric_eval: 3.02612	valid_1's custom_asymmetric_eval: 4.82187
# [1920]	training's custom_asymmetric_eval: 3.01971	valid_1's custom_asymmetric_eval: 4.82211
# [1940]	training's custom_asymmetric_eval: 3.01268	valid_1's custom_asymmetric_eval: 4.82072
# [1960]	training's custom_asymmetric_eval: 3.00657	valid_1's custom_asymmetric_eval: 4.82067
# [1980]	training's custom_asymmetric_eval: 2.99998	valid_1's custom_asymmetric_eval: 4.82021
# [2000]	training's custom_asymmetric_eval: 2.99365	valid_1's custom_asymmetric_eval: 4.81909
# [2020]	training's custom_asymmetric_eval: 2.98735	valid_1's custom_asymmetric_eval: 4.81846
# [2040]	training's custom_asymmetric_eval: 2.98067	valid_1's custom_asymmetric_eval: 4.81802
# [2060]	training's custom_asymmetric_eval: 2.97444	valid_1's custom_asymmetric_eval: 4.81788
# [2080]	training's custom_asymmetric_eval: 2.96783	valid_1's custom_asymmetric_eval: 4.81603
# [2100]	training's custom_asymmetric_eval: 2.9617	valid_1's custom_asymmetric_eval: 4.81497
# [2120]	training's custom_asymmetric_eval: 2.95554	valid_1's custom_asymmetric_eval: 4.81505
# [2140]	training's custom_asymmetric_eval: 2.94938	valid_1's custom_asymmetric_eval: 4.81448
# [2160]	training's custom_asymmetric_eval: 2.94305	valid_1's custom_asymmetric_eval: 4.81385
# [2180]	training's custom_asymmetric_eval: 2.93593	valid_1's custom_asymmetric_eval: 4.81169
# [2200]	training's custom_asymmetric_eval: 2.92938	valid_1's custom_asymmetric_eval: 4.81145
# [2220]	training's custom_asymmetric_eval: 2.92306	valid_1's custom_asymmetric_eval: 4.81059
# [2240]	training's custom_asymmetric_eval: 2.91712	valid_1's custom_asymmetric_eval: 4.80986
# [2260]	training's custom_asymmetric_eval: 2.91117	valid_1's custom_asymmetric_eval: 4.80958
# [2280]	training's custom_asymmetric_eval: 2.905	valid_1's custom_asymmetric_eval: 4.80979
# [2300]	training's custom_asymmetric_eval: 2.89907	valid_1's custom_asymmetric_eval: 4.80956
# [2320]	training's custom_asymmetric_eval: 2.89302	valid_1's custom_asymmetric_eval: 4.80955
# [2340]	training's custom_asymmetric_eval: 2.88714	valid_1's custom_asymmetric_eval: 4.80878
# [2360]	training's custom_asymmetric_eval: 2.88142	valid_1's custom_asymmetric_eval: 4.80835
# [2380]	training's custom_asymmetric_eval: 2.87594	valid_1's custom_asymmetric_eval: 4.80775
# [2400]	training's custom_asymmetric_eval: 2.87048	valid_1's custom_asymmetric_eval: 4.80765
# [2420]	training's custom_asymmetric_eval: 2.86482	valid_1's custom_asymmetric_eval: 4.80681
# [2440]	training's custom_asymmetric_eval: 2.85932	valid_1's custom_asymmetric_eval: 4.80638
# [2460]	training's custom_asymmetric_eval: 2.85357	valid_1's custom_asymmetric_eval: 4.80513
# [2480]	training's custom_asymmetric_eval: 2.84814	valid_1's custom_asymmetric_eval: 4.80465
# [2500]	training's custom_asymmetric_eval: 2.8428	valid_1's custom_asymmetric_eval: 4.80417
# [2520]	training's custom_asymmetric_eval: 2.83725	valid_1's custom_asymmetric_eval: 4.80397
# [2540]	training's custom_asymmetric_eval: 2.83193	valid_1's custom_asymmetric_eval: 4.80334
# [2560]	training's custom_asymmetric_eval: 2.82667	valid_1's custom_asymmetric_eval: 4.80288
# [2580]	training's custom_asymmetric_eval: 2.82091	valid_1's custom_asymmetric_eval: 4.80263
# [2600]	training's custom_asymmetric_eval: 2.81592	valid_1's custom_asymmetric_eval: 4.80268
# [2620]	training's custom_asymmetric_eval: 2.81095	valid_1's custom_asymmetric_eval: 4.80215
# [2640]	training's custom_asymmetric_eval: 2.80595	valid_1's custom_asymmetric_eval: 4.80145
# [2660]	training's custom_asymmetric_eval: 2.80103	valid_1's custom_asymmetric_eval: 4.80082
# [2680]	training's custom_asymmetric_eval: 2.79583	valid_1's custom_asymmetric_eval: 4.80116
# [2700]	training's custom_asymmetric_eval: 2.79104	valid_1's custom_asymmetric_eval: 4.80113
# [2720]	training's custom_asymmetric_eval: 2.78547	valid_1's custom_asymmetric_eval: 4.79968
# [2740]	training's custom_asymmetric_eval: 2.78038	valid_1's custom_asymmetric_eval: 4.79919
# [2760]	training's custom_asymmetric_eval: 2.77533	valid_1's custom_asymmetric_eval: 4.79931
# [2780]	training's custom_asymmetric_eval: 2.7707	valid_1's custom_asymmetric_eval: 4.79963
# Early stopping, best iteration is:
# [2735]	training's custom_asymmetric_eval: 2.7817	valid_1's custom_asymmetric_eval: 4.79904
# --------------------------------------------------
#
#
# Training fold 4
# Training until validation scores don't improve for 50 rounds
# [20]	training's custom_asymmetric_eval: 5.9194	valid_1's custom_asymmetric_eval: 6.44152
# [40]	training's custom_asymmetric_eval: 5.26606	valid_1's custom_asymmetric_eval: 6.05984
# [60]	training's custom_asymmetric_eval: 5.01771	valid_1's custom_asymmetric_eval: 5.92786
# [80]	training's custom_asymmetric_eval: 4.84428	valid_1's custom_asymmetric_eval: 5.83881
# [100]	training's custom_asymmetric_eval: 4.71502	valid_1's custom_asymmetric_eval: 5.78254
# [120]	training's custom_asymmetric_eval: 4.61898	valid_1's custom_asymmetric_eval: 5.75104
# [140]	training's custom_asymmetric_eval: 4.52943	valid_1's custom_asymmetric_eval: 5.7165
# [160]	training's custom_asymmetric_eval: 4.45843	valid_1's custom_asymmetric_eval: 5.69392
# [180]	training's custom_asymmetric_eval: 4.39853	valid_1's custom_asymmetric_eval: 5.66829
# [200]	training's custom_asymmetric_eval: 4.34477	valid_1's custom_asymmetric_eval: 5.65259
# [220]	training's custom_asymmetric_eval: 4.29534	valid_1's custom_asymmetric_eval: 5.63838
# [240]	training's custom_asymmetric_eval: 4.2475	valid_1's custom_asymmetric_eval: 5.62416
# [260]	training's custom_asymmetric_eval: 4.20244	valid_1's custom_asymmetric_eval: 5.60562
# [280]	training's custom_asymmetric_eval: 4.16258	valid_1's custom_asymmetric_eval: 5.59179
# [300]	training's custom_asymmetric_eval: 4.12613	valid_1's custom_asymmetric_eval: 5.57935
# [320]	training's custom_asymmetric_eval: 4.09015	valid_1's custom_asymmetric_eval: 5.56354
# [340]	training's custom_asymmetric_eval: 4.05516	valid_1's custom_asymmetric_eval: 5.54988
# [360]	training's custom_asymmetric_eval: 4.02067	valid_1's custom_asymmetric_eval: 5.53471
# [380]	training's custom_asymmetric_eval: 3.99014	valid_1's custom_asymmetric_eval: 5.53051
# [400]	training's custom_asymmetric_eval: 3.96349	valid_1's custom_asymmetric_eval: 5.52246
# [420]	training's custom_asymmetric_eval: 3.93768	valid_1's custom_asymmetric_eval: 5.51394
# [440]	training's custom_asymmetric_eval: 3.91331	valid_1's custom_asymmetric_eval: 5.50857
# [460]	training's custom_asymmetric_eval: 3.8853	valid_1's custom_asymmetric_eval: 5.50151
# [480]	training's custom_asymmetric_eval: 3.86166	valid_1's custom_asymmetric_eval: 5.49883
# [500]	training's custom_asymmetric_eval: 3.83966	valid_1's custom_asymmetric_eval: 5.49784
# [520]	training's custom_asymmetric_eval: 3.81587	valid_1's custom_asymmetric_eval: 5.49293
# [540]	training's custom_asymmetric_eval: 3.79472	valid_1's custom_asymmetric_eval: 5.48798
# [560]	training's custom_asymmetric_eval: 3.77353	valid_1's custom_asymmetric_eval: 5.48338
# [580]	training's custom_asymmetric_eval: 3.75238	valid_1's custom_asymmetric_eval: 5.48253
# [600]	training's custom_asymmetric_eval: 3.73113	valid_1's custom_asymmetric_eval: 5.47804
# [620]	training's custom_asymmetric_eval: 3.71337	valid_1's custom_asymmetric_eval: 5.47534
# [640]	training's custom_asymmetric_eval: 3.6962	valid_1's custom_asymmetric_eval: 5.47381
# [660]	training's custom_asymmetric_eval: 3.67746	valid_1's custom_asymmetric_eval: 5.46842
# [680]	training's custom_asymmetric_eval: 3.659	valid_1's custom_asymmetric_eval: 5.46395
# [700]	training's custom_asymmetric_eval: 3.6426	valid_1's custom_asymmetric_eval: 5.46057
# [720]	training's custom_asymmetric_eval: 3.62651	valid_1's custom_asymmetric_eval: 5.45806
# [740]	training's custom_asymmetric_eval: 3.60989	valid_1's custom_asymmetric_eval: 5.4539
# [760]	training's custom_asymmetric_eval: 3.59499	valid_1's custom_asymmetric_eval: 5.45352
# [780]	training's custom_asymmetric_eval: 3.57813	valid_1's custom_asymmetric_eval: 5.45065
# [800]	training's custom_asymmetric_eval: 3.56322	valid_1's custom_asymmetric_eval: 5.44933
# [820]	training's custom_asymmetric_eval: 3.54938	valid_1's custom_asymmetric_eval: 5.44658
# [840]	training's custom_asymmetric_eval: 3.53477	valid_1's custom_asymmetric_eval: 5.44472
# [860]	training's custom_asymmetric_eval: 3.51983	valid_1's custom_asymmetric_eval: 5.44117
# [880]	training's custom_asymmetric_eval: 3.50601	valid_1's custom_asymmetric_eval: 5.43757
# [900]	training's custom_asymmetric_eval: 3.49259	valid_1's custom_asymmetric_eval: 5.43717
# [920]	training's custom_asymmetric_eval: 3.47892	valid_1's custom_asymmetric_eval: 5.43372
# [940]	training's custom_asymmetric_eval: 3.46552	valid_1's custom_asymmetric_eval: 5.43401
# [960]	training's custom_asymmetric_eval: 3.45239	valid_1's custom_asymmetric_eval: 5.43271
# [980]	training's custom_asymmetric_eval: 3.4388	valid_1's custom_asymmetric_eval: 5.43149
# [1000]	training's custom_asymmetric_eval: 3.42492	valid_1's custom_asymmetric_eval: 5.42783
# [1020]	training's custom_asymmetric_eval: 3.41325	valid_1's custom_asymmetric_eval: 5.42519
# [1040]	training's custom_asymmetric_eval: 3.40204	valid_1's custom_asymmetric_eval: 5.42318
# [1060]	training's custom_asymmetric_eval: 3.39043	valid_1's custom_asymmetric_eval: 5.42075
# [1080]	training's custom_asymmetric_eval: 3.37847	valid_1's custom_asymmetric_eval: 5.41776
# [1100]	training's custom_asymmetric_eval: 3.36711	valid_1's custom_asymmetric_eval: 5.41458
# [1120]	training's custom_asymmetric_eval: 3.35661	valid_1's custom_asymmetric_eval: 5.41203
# [1140]	training's custom_asymmetric_eval: 3.34475	valid_1's custom_asymmetric_eval: 5.41017
# [1160]	training's custom_asymmetric_eval: 3.33441	valid_1's custom_asymmetric_eval: 5.4092
# [1180]	training's custom_asymmetric_eval: 3.32347	valid_1's custom_asymmetric_eval: 5.40688
# [1200]	training's custom_asymmetric_eval: 3.31303	valid_1's custom_asymmetric_eval: 5.40482
# [1220]	training's custom_asymmetric_eval: 3.30249	valid_1's custom_asymmetric_eval: 5.40283
# [1240]	training's custom_asymmetric_eval: 3.29262	valid_1's custom_asymmetric_eval: 5.40311
# [1260]	training's custom_asymmetric_eval: 3.28275	valid_1's custom_asymmetric_eval: 5.40053
# [1280]	training's custom_asymmetric_eval: 3.27297	valid_1's custom_asymmetric_eval: 5.39862
# [1300]	training's custom_asymmetric_eval: 3.26329	valid_1's custom_asymmetric_eval: 5.3993
# [1320]	training's custom_asymmetric_eval: 3.2541	valid_1's custom_asymmetric_eval: 5.39838
# [1340]	training's custom_asymmetric_eval: 3.2449	valid_1's custom_asymmetric_eval: 5.39656
# [1360]	training's custom_asymmetric_eval: 3.23598	valid_1's custom_asymmetric_eval: 5.39651
# [1380]	training's custom_asymmetric_eval: 3.22739	valid_1's custom_asymmetric_eval: 5.39449
# [1400]	training's custom_asymmetric_eval: 3.21899	valid_1's custom_asymmetric_eval: 5.39262
# [1420]	training's custom_asymmetric_eval: 3.21009	valid_1's custom_asymmetric_eval: 5.3914
# [1440]	training's custom_asymmetric_eval: 3.20145	valid_1's custom_asymmetric_eval: 5.3888
# [1460]	training's custom_asymmetric_eval: 3.193	valid_1's custom_asymmetric_eval: 5.3886
# [1480]	training's custom_asymmetric_eval: 3.1845	valid_1's custom_asymmetric_eval: 5.38831
# [1500]	training's custom_asymmetric_eval: 3.17501	valid_1's custom_asymmetric_eval: 5.3875
# [1520]	training's custom_asymmetric_eval: 3.16669	valid_1's custom_asymmetric_eval: 5.38437
# [1540]	training's custom_asymmetric_eval: 3.15855	valid_1's custom_asymmetric_eval: 5.38438
# [1560]	training's custom_asymmetric_eval: 3.14952	valid_1's custom_asymmetric_eval: 5.38124
# [1580]	training's custom_asymmetric_eval: 3.14161	valid_1's custom_asymmetric_eval: 5.38058
# [1600]	training's custom_asymmetric_eval: 3.13272	valid_1's custom_asymmetric_eval: 5.37941
# [1620]	training's custom_asymmetric_eval: 3.1247	valid_1's custom_asymmetric_eval: 5.37903
# [1640]	training's custom_asymmetric_eval: 3.11715	valid_1's custom_asymmetric_eval: 5.37844
# [1660]	training's custom_asymmetric_eval: 3.10926	valid_1's custom_asymmetric_eval: 5.37683
# [1680]	training's custom_asymmetric_eval: 3.1015	valid_1's custom_asymmetric_eval: 5.37531
# [1700]	training's custom_asymmetric_eval: 3.09393	valid_1's custom_asymmetric_eval: 5.37441
# [1720]	training's custom_asymmetric_eval: 3.08613	valid_1's custom_asymmetric_eval: 5.37329
# [1740]	training's custom_asymmetric_eval: 3.07846	valid_1's custom_asymmetric_eval: 5.37271
# [1760]	training's custom_asymmetric_eval: 3.0714	valid_1's custom_asymmetric_eval: 5.37027
# [1780]	training's custom_asymmetric_eval: 3.06422	valid_1's custom_asymmetric_eval: 5.36761
# [1800]	training's custom_asymmetric_eval: 3.05699	valid_1's custom_asymmetric_eval: 5.36739
# [1820]	training's custom_asymmetric_eval: 3.05042	valid_1's custom_asymmetric_eval: 5.36757
# [1840]	training's custom_asymmetric_eval: 3.04362	valid_1's custom_asymmetric_eval: 5.36696
# [1860]	training's custom_asymmetric_eval: 3.03665	valid_1's custom_asymmetric_eval: 5.36702
# [1880]	training's custom_asymmetric_eval: 3.02949	valid_1's custom_asymmetric_eval: 5.36515
# [1900]	training's custom_asymmetric_eval: 3.02214	valid_1's custom_asymmetric_eval: 5.36429
# [1920]	training's custom_asymmetric_eval: 3.01521	valid_1's custom_asymmetric_eval: 5.36378
# [1940]	training's custom_asymmetric_eval: 3.00796	valid_1's custom_asymmetric_eval: 5.36321
# [1960]	training's custom_asymmetric_eval: 3.00118	valid_1's custom_asymmetric_eval: 5.3634
# [1980]	training's custom_asymmetric_eval: 2.99469	valid_1's custom_asymmetric_eval: 5.36227
# [2000]	training's custom_asymmetric_eval: 2.98782	valid_1's custom_asymmetric_eval: 5.36195
# [2020]	training's custom_asymmetric_eval: 2.98153	valid_1's custom_asymmetric_eval: 5.36219
# [2040]	training's custom_asymmetric_eval: 2.9753	valid_1's custom_asymmetric_eval: 5.36152
# [2060]	training's custom_asymmetric_eval: 2.96849	valid_1's custom_asymmetric_eval: 5.36122
# [2080]	training's custom_asymmetric_eval: 2.96231	valid_1's custom_asymmetric_eval: 5.36072
# [2100]	training's custom_asymmetric_eval: 2.95613	valid_1's custom_asymmetric_eval: 5.3604
# [2120]	training's custom_asymmetric_eval: 2.94958	valid_1's custom_asymmetric_eval: 5.36003
# [2140]	training's custom_asymmetric_eval: 2.94344	valid_1's custom_asymmetric_eval: 5.35806
# [2160]	training's custom_asymmetric_eval: 2.93726	valid_1's custom_asymmetric_eval: 5.35684
# [2180]	training's custom_asymmetric_eval: 2.93148	valid_1's custom_asymmetric_eval: 5.35628
# [2200]	training's custom_asymmetric_eval: 2.92557	valid_1's custom_asymmetric_eval: 5.35588
# [2220]	training's custom_asymmetric_eval: 2.91967	valid_1's custom_asymmetric_eval: 5.35528
# [2240]	training's custom_asymmetric_eval: 2.91383	valid_1's custom_asymmetric_eval: 5.35435
# [2260]	training's custom_asymmetric_eval: 2.90796	valid_1's custom_asymmetric_eval: 5.35413
# [2280]	training's custom_asymmetric_eval: 2.90213	valid_1's custom_asymmetric_eval: 5.35408
# [2300]	training's custom_asymmetric_eval: 2.89594	valid_1's custom_asymmetric_eval: 5.35211
# [2320]	training's custom_asymmetric_eval: 2.88979	valid_1's custom_asymmetric_eval: 5.35132
# [2340]	training's custom_asymmetric_eval: 2.8837	valid_1's custom_asymmetric_eval: 5.35107
# [2360]	training's custom_asymmetric_eval: 2.878	valid_1's custom_asymmetric_eval: 5.35066
# [2380]	training's custom_asymmetric_eval: 2.87241	valid_1's custom_asymmetric_eval: 5.34996
# [2400]	training's custom_asymmetric_eval: 2.86674	valid_1's custom_asymmetric_eval: 5.34934
# [2420]	training's custom_asymmetric_eval: 2.86081	valid_1's custom_asymmetric_eval: 5.34845
# [2440]	training's custom_asymmetric_eval: 2.85541	valid_1's custom_asymmetric_eval: 5.34898
# [2460]	training's custom_asymmetric_eval: 2.85021	valid_1's custom_asymmetric_eval: 5.34861
# [2480]	training's custom_asymmetric_eval: 2.84479	valid_1's custom_asymmetric_eval: 5.34816
# [2500]	training's custom_asymmetric_eval: 2.83942	valid_1's custom_asymmetric_eval: 5.34819
# [2520]	training's custom_asymmetric_eval: 2.83442	valid_1's custom_asymmetric_eval: 5.34851
# Early stopping, best iteration is:
# [2483]	training's custom_asymmetric_eval: 2.84399	valid_1's custom_asymmetric_eval: 5.34784
# --------------------------------------------------
#
#
# Training fold 5
# Training until validation scores don't improve for 50 rounds
# [20]	training's custom_asymmetric_eval: 5.99673	valid_1's custom_asymmetric_eval: 5.98689
# [40]	training's custom_asymmetric_eval: 5.33251	valid_1's custom_asymmetric_eval: 5.48435
# [60]	training's custom_asymmetric_eval: 5.04124	valid_1's custom_asymmetric_eval: 5.33194
# [80]	training's custom_asymmetric_eval: 4.86941	valid_1's custom_asymmetric_eval: 5.25061
# [100]	training's custom_asymmetric_eval: 4.73171	valid_1's custom_asymmetric_eval: 5.19334
# [120]	training's custom_asymmetric_eval: 4.62873	valid_1's custom_asymmetric_eval: 5.15937
# [140]	training's custom_asymmetric_eval: 4.54605	valid_1's custom_asymmetric_eval: 5.13242
# [160]	training's custom_asymmetric_eval: 4.47645	valid_1's custom_asymmetric_eval: 5.1157
# [180]	training's custom_asymmetric_eval: 4.41663	valid_1's custom_asymmetric_eval: 5.10102
# [200]	training's custom_asymmetric_eval: 4.36106	valid_1's custom_asymmetric_eval: 5.0842
# [220]	training's custom_asymmetric_eval: 4.31052	valid_1's custom_asymmetric_eval: 5.0694
# [240]	training's custom_asymmetric_eval: 4.26412	valid_1's custom_asymmetric_eval: 5.06005
# [260]	training's custom_asymmetric_eval: 4.2197	valid_1's custom_asymmetric_eval: 5.04945
# [280]	training's custom_asymmetric_eval: 4.17841	valid_1's custom_asymmetric_eval: 5.03881
# [300]	training's custom_asymmetric_eval: 4.14138	valid_1's custom_asymmetric_eval: 5.03139
# [320]	training's custom_asymmetric_eval: 4.10357	valid_1's custom_asymmetric_eval: 5.02254
# [340]	training's custom_asymmetric_eval: 4.06977	valid_1's custom_asymmetric_eval: 5.01329
# [360]	training's custom_asymmetric_eval: 4.03466	valid_1's custom_asymmetric_eval: 5.00477
# [380]	training's custom_asymmetric_eval: 4.00341	valid_1's custom_asymmetric_eval: 4.99908
# [400]	training's custom_asymmetric_eval: 3.97396	valid_1's custom_asymmetric_eval: 4.9941
# [420]	training's custom_asymmetric_eval: 3.94384	valid_1's custom_asymmetric_eval: 4.98847
# [440]	training's custom_asymmetric_eval: 3.91742	valid_1's custom_asymmetric_eval: 4.98527
# [460]	training's custom_asymmetric_eval: 3.89358	valid_1's custom_asymmetric_eval: 4.98259
# [480]	training's custom_asymmetric_eval: 3.87141	valid_1's custom_asymmetric_eval: 4.97877
# [500]	training's custom_asymmetric_eval: 3.84798	valid_1's custom_asymmetric_eval: 4.97392
# [520]	training's custom_asymmetric_eval: 3.82672	valid_1's custom_asymmetric_eval: 4.97035
# [540]	training's custom_asymmetric_eval: 3.80438	valid_1's custom_asymmetric_eval: 4.96569
# [560]	training's custom_asymmetric_eval: 3.78468	valid_1's custom_asymmetric_eval: 4.96294
# [580]	training's custom_asymmetric_eval: 3.76467	valid_1's custom_asymmetric_eval: 4.96104
# [600]	training's custom_asymmetric_eval: 3.74273	valid_1's custom_asymmetric_eval: 4.95381
# [620]	training's custom_asymmetric_eval: 3.7225	valid_1's custom_asymmetric_eval: 4.95044
# [640]	training's custom_asymmetric_eval: 3.70427	valid_1's custom_asymmetric_eval: 4.94681
# [660]	training's custom_asymmetric_eval: 3.6839	valid_1's custom_asymmetric_eval: 4.94147
# [680]	training's custom_asymmetric_eval: 3.66661	valid_1's custom_asymmetric_eval: 4.94036
# [700]	training's custom_asymmetric_eval: 3.64869	valid_1's custom_asymmetric_eval: 4.93894
# [720]	training's custom_asymmetric_eval: 3.63108	valid_1's custom_asymmetric_eval: 4.93599
# [740]	training's custom_asymmetric_eval: 3.61501	valid_1's custom_asymmetric_eval: 4.93303
# [760]	training's custom_asymmetric_eval: 3.59863	valid_1's custom_asymmetric_eval: 4.93062
# [780]	training's custom_asymmetric_eval: 3.58259	valid_1's custom_asymmetric_eval: 4.92736
# [800]	training's custom_asymmetric_eval: 3.56742	valid_1's custom_asymmetric_eval: 4.9255
# [820]	training's custom_asymmetric_eval: 3.55228	valid_1's custom_asymmetric_eval: 4.9233
# [840]	training's custom_asymmetric_eval: 3.53691	valid_1's custom_asymmetric_eval: 4.92078
# [860]	training's custom_asymmetric_eval: 3.52303	valid_1's custom_asymmetric_eval: 4.92015
# [880]	training's custom_asymmetric_eval: 3.50847	valid_1's custom_asymmetric_eval: 4.91708
# [900]	training's custom_asymmetric_eval: 3.49485	valid_1's custom_asymmetric_eval: 4.914
# [920]	training's custom_asymmetric_eval: 3.48119	valid_1's custom_asymmetric_eval: 4.91202
# [940]	training's custom_asymmetric_eval: 3.46903	valid_1's custom_asymmetric_eval: 4.9113
# [960]	training's custom_asymmetric_eval: 3.45501	valid_1's custom_asymmetric_eval: 4.9093
# [980]	training's custom_asymmetric_eval: 3.44294	valid_1's custom_asymmetric_eval: 4.90817
# [1000]	training's custom_asymmetric_eval: 3.43025	valid_1's custom_asymmetric_eval: 4.90683
# [1020]	training's custom_asymmetric_eval: 3.41761	valid_1's custom_asymmetric_eval: 4.90542
# [1040]	training's custom_asymmetric_eval: 3.40465	valid_1's custom_asymmetric_eval: 4.90339
# [1060]	training's custom_asymmetric_eval: 3.39134	valid_1's custom_asymmetric_eval: 4.90083
# [1080]	training's custom_asymmetric_eval: 3.37997	valid_1's custom_asymmetric_eval: 4.90006
# [1100]	training's custom_asymmetric_eval: 3.36844	valid_1's custom_asymmetric_eval: 4.89933
# [1120]	training's custom_asymmetric_eval: 3.35674	valid_1's custom_asymmetric_eval: 4.89841
# [1140]	training's custom_asymmetric_eval: 3.34502	valid_1's custom_asymmetric_eval: 4.89745
# [1160]	training's custom_asymmetric_eval: 3.33368	valid_1's custom_asymmetric_eval: 4.89425
# [1180]	training's custom_asymmetric_eval: 3.32341	valid_1's custom_asymmetric_eval: 4.89313
# [1200]	training's custom_asymmetric_eval: 3.31273	valid_1's custom_asymmetric_eval: 4.89159
# [1220]	training's custom_asymmetric_eval: 3.30222	valid_1's custom_asymmetric_eval: 4.89124
# [1240]	training's custom_asymmetric_eval: 3.29196	valid_1's custom_asymmetric_eval: 4.89071
# [1260]	training's custom_asymmetric_eval: 3.28222	valid_1's custom_asymmetric_eval: 4.89037
# [1280]	training's custom_asymmetric_eval: 3.27188	valid_1's custom_asymmetric_eval: 4.889
# [1300]	training's custom_asymmetric_eval: 3.26226	valid_1's custom_asymmetric_eval: 4.88918
# [1320]	training's custom_asymmetric_eval: 3.25235	valid_1's custom_asymmetric_eval: 4.889
# [1340]	training's custom_asymmetric_eval: 3.24255	valid_1's custom_asymmetric_eval: 4.88834
# [1360]	training's custom_asymmetric_eval: 3.23291	valid_1's custom_asymmetric_eval: 4.88729
# [1380]	training's custom_asymmetric_eval: 3.22248	valid_1's custom_asymmetric_eval: 4.88518
# [1400]	training's custom_asymmetric_eval: 3.21289	valid_1's custom_asymmetric_eval: 4.88399
# [1420]	training's custom_asymmetric_eval: 3.20412	valid_1's custom_asymmetric_eval: 4.88316
# [1440]	training's custom_asymmetric_eval: 3.19578	valid_1's custom_asymmetric_eval: 4.88285
# [1460]	training's custom_asymmetric_eval: 3.18693	valid_1's custom_asymmetric_eval: 4.88228
# [1480]	training's custom_asymmetric_eval: 3.17812	valid_1's custom_asymmetric_eval: 4.8823
# [1500]	training's custom_asymmetric_eval: 3.16927	valid_1's custom_asymmetric_eval: 4.88072
# [1520]	training's custom_asymmetric_eval: 3.16118	valid_1's custom_asymmetric_eval: 4.88027
# [1540]	training's custom_asymmetric_eval: 3.15291	valid_1's custom_asymmetric_eval: 4.87994
# [1560]	training's custom_asymmetric_eval: 3.14479	valid_1's custom_asymmetric_eval: 4.87912
# [1580]	training's custom_asymmetric_eval: 3.13653	valid_1's custom_asymmetric_eval: 4.87803
# [1600]	training's custom_asymmetric_eval: 3.12863	valid_1's custom_asymmetric_eval: 4.87753
# [1620]	training's custom_asymmetric_eval: 3.12022	valid_1's custom_asymmetric_eval: 4.87692
# [1640]	training's custom_asymmetric_eval: 3.11217	valid_1's custom_asymmetric_eval: 4.87677
# [1660]	training's custom_asymmetric_eval: 3.10445	valid_1's custom_asymmetric_eval: 4.87688
# Early stopping, best iteration is:
# [1615]	training's custom_asymmetric_eval: 3.12219	valid_1's custom_asymmetric_eval: 4.87615
# --------------------------------------------------
#
#
# Training fold 6
# Training until validation scores don't improve for 50 rounds
# [20]	training's custom_asymmetric_eval: 5.88542	valid_1's custom_asymmetric_eval: 6.76089
# [40]	training's custom_asymmetric_eval: 5.24647	valid_1's custom_asymmetric_eval: 6.25422
# [60]	training's custom_asymmetric_eval: 4.98849	valid_1's custom_asymmetric_eval: 6.11718
# [80]	training's custom_asymmetric_eval: 4.81977	valid_1's custom_asymmetric_eval: 6.0263
# [100]	training's custom_asymmetric_eval: 4.69358	valid_1's custom_asymmetric_eval: 5.98176
# [120]	training's custom_asymmetric_eval: 4.59576	valid_1's custom_asymmetric_eval: 5.94225
# [140]	training's custom_asymmetric_eval: 4.5182	valid_1's custom_asymmetric_eval: 5.91101
# [160]	training's custom_asymmetric_eval: 4.45025	valid_1's custom_asymmetric_eval: 5.89328
# [180]	training's custom_asymmetric_eval: 4.38965	valid_1's custom_asymmetric_eval: 5.87423
# [200]	training's custom_asymmetric_eval: 4.32861	valid_1's custom_asymmetric_eval: 5.85295
# [220]	training's custom_asymmetric_eval: 4.27945	valid_1's custom_asymmetric_eval: 5.84292
# [240]	training's custom_asymmetric_eval: 4.23403	valid_1's custom_asymmetric_eval: 5.82622
# [260]	training's custom_asymmetric_eval: 4.19478	valid_1's custom_asymmetric_eval: 5.81505
# [280]	training's custom_asymmetric_eval: 4.15522	valid_1's custom_asymmetric_eval: 5.80271
# [300]	training's custom_asymmetric_eval: 4.11948	valid_1's custom_asymmetric_eval: 5.79266
# [320]	training's custom_asymmetric_eval: 4.08399	valid_1's custom_asymmetric_eval: 5.78028
# [340]	training's custom_asymmetric_eval: 4.05175	valid_1's custom_asymmetric_eval: 5.77463
# [360]	training's custom_asymmetric_eval: 4.0189	valid_1's custom_asymmetric_eval: 5.76324
# [380]	training's custom_asymmetric_eval: 3.9847	valid_1's custom_asymmetric_eval: 5.74894
# [400]	training's custom_asymmetric_eval: 3.95477	valid_1's custom_asymmetric_eval: 5.74094
# [420]	training's custom_asymmetric_eval: 3.92606	valid_1's custom_asymmetric_eval: 5.73533
# [440]	training's custom_asymmetric_eval: 3.8989	valid_1's custom_asymmetric_eval: 5.72348
# [460]	training's custom_asymmetric_eval: 3.87302	valid_1's custom_asymmetric_eval: 5.7188
# [480]	training's custom_asymmetric_eval: 3.84773	valid_1's custom_asymmetric_eval: 5.71301
# [500]	training's custom_asymmetric_eval: 3.82498	valid_1's custom_asymmetric_eval: 5.706
# [520]	training's custom_asymmetric_eval: 3.80411	valid_1's custom_asymmetric_eval: 5.70375
# [540]	training's custom_asymmetric_eval: 3.78	valid_1's custom_asymmetric_eval: 5.69601
# [560]	training's custom_asymmetric_eval: 3.76026	valid_1's custom_asymmetric_eval: 5.6939
# [580]	training's custom_asymmetric_eval: 3.7394	valid_1's custom_asymmetric_eval: 5.68954
# [600]	training's custom_asymmetric_eval: 3.71926	valid_1's custom_asymmetric_eval: 5.68693
# [620]	training's custom_asymmetric_eval: 3.70073	valid_1's custom_asymmetric_eval: 5.68268
# [640]	training's custom_asymmetric_eval: 3.67989	valid_1's custom_asymmetric_eval: 5.68009
# [660]	training's custom_asymmetric_eval: 3.66116	valid_1's custom_asymmetric_eval: 5.67458
# [680]	training's custom_asymmetric_eval: 3.64469	valid_1's custom_asymmetric_eval: 5.67113
# [700]	training's custom_asymmetric_eval: 3.62688	valid_1's custom_asymmetric_eval: 5.6658
# [720]	training's custom_asymmetric_eval: 3.60975	valid_1's custom_asymmetric_eval: 5.66289
# [740]	training's custom_asymmetric_eval: 3.59225	valid_1's custom_asymmetric_eval: 5.6617
# [760]	training's custom_asymmetric_eval: 3.57723	valid_1's custom_asymmetric_eval: 5.6615
# [780]	training's custom_asymmetric_eval: 3.5609	valid_1's custom_asymmetric_eval: 5.65789
# [800]	training's custom_asymmetric_eval: 3.54588	valid_1's custom_asymmetric_eval: 5.65545
# [820]	training's custom_asymmetric_eval: 3.5314	valid_1's custom_asymmetric_eval: 5.65433
# [840]	training's custom_asymmetric_eval: 3.5169	valid_1's custom_asymmetric_eval: 5.65209
# [860]	training's custom_asymmetric_eval: 3.50252	valid_1's custom_asymmetric_eval: 5.64593
# [880]	training's custom_asymmetric_eval: 3.48828	valid_1's custom_asymmetric_eval: 5.64377
# [900]	training's custom_asymmetric_eval: 3.47443	valid_1's custom_asymmetric_eval: 5.64062
# [920]	training's custom_asymmetric_eval: 3.46124	valid_1's custom_asymmetric_eval: 5.63884
# [940]	training's custom_asymmetric_eval: 3.44849	valid_1's custom_asymmetric_eval: 5.63814
# [960]	training's custom_asymmetric_eval: 3.43554	valid_1's custom_asymmetric_eval: 5.6353
# [980]	training's custom_asymmetric_eval: 3.42277	valid_1's custom_asymmetric_eval: 5.63331
# [1000]	training's custom_asymmetric_eval: 3.41005	valid_1's custom_asymmetric_eval: 5.63229
# [1020]	training's custom_asymmetric_eval: 3.39784	valid_1's custom_asymmetric_eval: 5.62904
# [1040]	training's custom_asymmetric_eval: 3.38582	valid_1's custom_asymmetric_eval: 5.6275
# [1060]	training's custom_asymmetric_eval: 3.37237	valid_1's custom_asymmetric_eval: 5.62312
# [1080]	training's custom_asymmetric_eval: 3.3608	valid_1's custom_asymmetric_eval: 5.62027
# [1100]	training's custom_asymmetric_eval: 3.35048	valid_1's custom_asymmetric_eval: 5.61925
# [1120]	training's custom_asymmetric_eval: 3.33928	valid_1's custom_asymmetric_eval: 5.61838
# [1140]	training's custom_asymmetric_eval: 3.32744	valid_1's custom_asymmetric_eval: 5.61457
# [1160]	training's custom_asymmetric_eval: 3.31624	valid_1's custom_asymmetric_eval: 5.61231
# [1180]	training's custom_asymmetric_eval: 3.30589	valid_1's custom_asymmetric_eval: 5.61016
# [1200]	training's custom_asymmetric_eval: 3.29512	valid_1's custom_asymmetric_eval: 5.6082
# [1220]	training's custom_asymmetric_eval: 3.28483	valid_1's custom_asymmetric_eval: 5.60768
# [1240]	training's custom_asymmetric_eval: 3.2749	valid_1's custom_asymmetric_eval: 5.60654
# [1260]	training's custom_asymmetric_eval: 3.26402	valid_1's custom_asymmetric_eval: 5.60521
# [1280]	training's custom_asymmetric_eval: 3.25404	valid_1's custom_asymmetric_eval: 5.60393
# [1300]	training's custom_asymmetric_eval: 3.24448	valid_1's custom_asymmetric_eval: 5.60499
# [1320]	training's custom_asymmetric_eval: 3.23428	valid_1's custom_asymmetric_eval: 5.60368
# Early stopping, best iteration is:
# [1274]	training's custom_asymmetric_eval: 3.2569	valid_1's custom_asymmetric_eval: 5.6036
# --------------------------------------------------
#
#
# Our out of folds rmse is 2.170344006790848

# %%
next_test.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-4f476e1c4fa4> in <module>
# ----> 1 next_test.head()
#
# NameError: name 'next_test' is not defined

# %%
data.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0b73fe40d24a> in <module>
# ----> 1 data.tail()
#
# NameError: name 'data' is not defined
